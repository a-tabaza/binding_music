# %%
import json
import requests
import numpy as np
import tempfile
import os

# %%
tracks = json.load(open('/workspace/fairouz/fairouz_conf/fairouz/tracks_contextualized.json'))

# %%
tracks[list(tracks.keys())[0]]
# Out:
# {'track_title': 'True Colors',
#  'artist_name': 'The Weeknd',
#  'album_name': 'Starboy (Deluxe)',
#  'deezer_id': '2189328287',
#  'discogs_id': '',
#  'lyrics': {'lyrics': "[Intro]\r\nYeah, uh\r\nYeah\r\nYeah\r\n\r\n[Verse 1]\r\nTell me the truth, baby girl, who else been with you?\r\nIt's gon' come to my attention either way, yeah (Uh, yeah)\r\nAnd I understand, baby girl, we all have a past\r\nI'd much rather hear the truth come straight from you (Yeah)\r\n\r\n[Pre-Chorus]\r\nSo if I love you (If I love you)\r\nIt'd be just for you (It'd be just for you)\r\nSo when I'm touchin' you (Touchin' you)\r\nCan I trust in you? (Trust in you)\r\nCan I trust in you? Oh, babe (Trust in you)\r\n\r\n[Chorus]\r\nGirl, come show me your true colors\r\nPaint me a picture with your true colors\r\nThese are the questions of a new lover\r\nTrue colors, true colors\r\nGirl, come show me your true colors\r\nPaint me a picture with your true colors\r\nThese are confessions of a new lover (Hey, hey)\r\nTrue colors, true colors (Woo)\r\n\r\n[Verse 2]\r\nWhat's done is done now that I'm the only one\r\nIf you tell me, I'll accept what you've been through, oh yeah\r\nAnd I don't believe all this inconsistency\r\nI've been hearin' different stories about you\r\n\r\n[Pre-Chorus]\r\nSo if I love you (If I love you)\r\nIt'd be just for you (It'd be just for you)\r\nSo when I'm touchin' you (Touchin' you)\r\nCan I trust in you? (Trust in you)\r\nCan I trust in you? Oh, babe (Trust in you, hey)\r\n\r\n[Chorus]\r\nGirl, come show me your true colors\r\nPaint me a picture with your true colors\r\nThese are the questions of a new lover\r\nTrue colors, true colors (Oh, baby)\r\nGirl, come show me your true colors (True)\r\nPaint me a picture with your true colors (True)\r\nThese are confessions of a new lover (True)\r\nTrue colors\r\n\r\n[Bridge]\r\nBaby, show me you're a keeper (Hey, oh)\r\nIt's been hard for me to keep up (Oh)\r\nYou've been tryna keep me in the dark (Oh)\r\nBut, baby girl, I see you (Oh)\r\nBaby, show me you're a keeper (Show me you're a keeper)\r\nIt's been hard for me to keep up (Hard for me to keep up)\r\nYou've been tryna keep me in the dark (Yeah, yeah, yeah)\r\nBut, baby girl, I see you, yeah\r\n\r\n[Chorus]\r\nGirl, come show me your true colors\r\nPaint me a picture with your true colors\r\nThese are the questions of a new lover\r\nTrue colors, true colors\r\nGirl, come show me your true colors\r\nPaint me a picture with your true colors\r\nThese are confessions of a new lover\r\nTrue colors, true colors",
#   'context': ['new lover',
#    'trust',
#    'true colors',
#    'past relationships',
#    'painting a picture'],
#   'summary': "The song is about a new relationship and the importance of trust and honesty in it. The singer asks the lover to reveal their true colors and past experiences, and expresses confusion about inconsistencies in their stories. The chorus repeats the phrase 'paint me a picture with your true colors' and 'these are confessions of a new lover', indicating the desire for transparency and understanding in the relationship.",
#   'emotional': ['desire for transparency',
#    'confusion',
#    'trust issues',
#    'longing',
#    'hopefulness']},
#  'image': 'https://e-cdns-images.dzcdn.net/images/cover/0d961a8d3d3c425a512bb79f2ad5c25d/500x500-000000-80-0-0.jpg',
#  'preview_url': 'https://cdns-preview-6.dzcdn.net/stream/c-6181e59423c76726ec936f24f4620d34-5.mp3',
#  'genres': ['R&B']}

# %%
def embed_lyrics(lyric):
    if lyric["lyrics"] == "":
        return np.zeros(1024)
    
    url = "https://w7852kszrbkrz2-4000.proxy.runpod.net/embed/"
    lyrics = {
        "lyrics_summary": lyric["summary"],
        "lexical_keywords": lyric["context"],
        "sentiment_keywords": lyric["emotional"]
    }
    headers = {
        'Content-Type': 'application/json',
        'Authorization': 'Bearer 543c7086-c880-45de-8bce-6c9c906293bb'
        }
    response = requests.post(url, json=lyrics, headers=headers)
    return np.array(json.loads(response.json())["embedding"])

# %%
def embed_images(images_url):
    url = f"https://w7852kszrbkrz2-4002.proxy.runpod.net/embed/"
    
    with tempfile.TemporaryDirectory() as temp_dir:
        temp_file_path = os.path.join(temp_dir, file.filename)

    # Save the uploaded file to the temporary directory
    with open(temp_file_path, 'wb') as temp_file:
        content = await file.read()
        temp_file.write(content)

    return np.array(json.loads(response.json())["embedding"])

# %%
from tqdm import tqdm

# %%
embeddings = []

# %%
for id, track in tqdm(tracks.items(), total=len(tracks.keys())):
    try:
        embeddings.append((id, embed_lyrics(track["lyrics"])))
    except Exception as e:
        print(e)

assert len(embeddings) == len(tracks.keys())
# Out:
# 100%|██████████| 822/822 [03:05<00:00,  4.44it/s]

# %%
embeddings_json = [{"id": id, "embedding": embedding.tolist()} for id, embedding in embeddings]

# %%
json.dump(embeddings_json, open("/workspace/fairouz/fairouz_conf/fairouz/lyrics_mxbai_embeddings.json", "w"))

# %%
metadatas = []

# %%
for emb in embeddings_json:
    md = tracks["all"]["tracks"][emb["id"]]
    md_new = {
        "track_name": md["track_name"],
        "artist_name": md["artist_name"],
        "album_name": md["album_name"],
        "genres": ", ".join(md["genres"]),
        "keywords": ", ".join(md["lyrics"]["context"]),
        "emotional": ", ".join(md["lyrics"]["emotional"]),
        "synopsis": md["lyrics"]["summary"]
    }
    metadatas.append(md_new)

# %%
np.array([emb[1] for emb in embeddings]).shape
# Out:
# (821, 1024)

# %%
len(metadatas)
# Out:
# 821

# %%
metadatas
# Out:
# [{'track_name': 'Are You What You Want to Be?',
#   'artist_name': 'Foster The People',
#   'album_name': 'Supermodel',
#   'genres': 'Alternative',
#   'keywords': 'Champs-Élysées, Djembe of Ghana, Fine lady from Belize, Dissidents, Revolution',
#   'emotional': 'fear, cowardice, reflection, struggle, self-doubt',
#   'synopsis': "The lyrics express the speaker's internal struggle with living up to their desires and dealing with the consequences of their actions. Themes of fear, cowardice, and self-reflection are present."},
#  {'track_name': 'Out In The Fields',
#   'artist_name': 'Gary Moore',
#   'album_name': 'All The Best',
#   'genres': 'Rock',
#   'keywords': 'equality, war, death, fighting, inequality',
#   'emotional': 'inequality, war, death, fighting, hopelessness',
#   'synopsis': 'The lyrics express the idea that in a war or conflict, all men are equal and no factor such as race or religion matters. The theme is one of equality and the inevitability of death.'},
#  {'track_name': 'Incredible Sauce (feat. Dave)',
#   'artist_name': 'Giggs',
#   'album_name': 'Zero Tolerance',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'Champions League, Henry, Matsuhisa, Gangster, Hustler',
#   'emotional': 'confident, hustler, judging, deals, Matsuhisa',
#   'synopsis': "The lyrics express the speaker's confidence and hustler mentality, with references to the Champions League, Matsuhisa restaurant, and being a gangster and hustler. The speaker also mentions judging people based on their appearance and actions, and making deals and deals, possibly involving drugs."},
#  {'track_name': 'Still Got The Blues',
#   'artist_name': 'Gary Moore',
#   'album_name': 'Still Got The Blues',
#   'genres': 'Rock',
#   'keywords': 'used to be, love, heart, price, pain',
#   'emotional': 'heart, love, pain, loss, blues',
#   'synopsis': "The lyrics describe past experiences of giving one's heart away in love and the resulting pain and loss."},
#  {'track_name': "She's Gone",
#   'artist_name': 'Steelheart',
#   'album_name': 'Steelheart',
#   'genres': 'Rock',
#   'keywords': 'love, loss, forgiveness, regret, apology',
#   'emotional': 'regret, longing, plea, apology, forgiveness',
#   'synopsis': 'The lyrics express regret, pleas for forgiveness, and a longing for the return of a lost love.'},
#  {'track_name': 'Bodies',
#   'artist_name': 'Drowning Pool',
#   'album_name': 'Sinner',
#   'genres': 'Rock',
#   'keywords': "Let the bodies hit the floor, Something's got to give, Fear, Hate, Drop",
#   'emotional': 'Fear, Hate, Let the bodies hit the floor, Drop, Give',
#   'synopsis': "The lyrics repeat the phrase 'Let the bodies hit the floor' suggesting a call to action or release, while also acknowledging the need for change with 'something's got to give'. The emotions expressed include fear and hate."},
#  {'track_name': 'Ounshoudat Al Matar',
#   'artist_name': 'Mohammed Abdo',
#   'album_name': 'Ounshoudat Al Matar',
#   'genres': '',
#   'keywords': '',
#   'emotional': '',
#   'synopsis': ''},
#  {'track_name': 'Helaf El Amar',
#   'artist_name': 'George Wassouf',
#   'album_name': 'El Hawa Sultan Rare Recordings',
#   'genres': 'Pop',
#   'keywords': 'moon, sw swords, love, eyes, hours',
#   'emotional': 'longing, love, desire, promise, hours',
#   'synopsis': 'The lyrics speak of a promise made by the moon and the longing for a beloved, with references to eyes, hours, and swords.'},
#  {'track_name': 'Flashing Lights',
#   'artist_name': 'Kanye West',
#   'album_name': 'Graduation',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'Flashing lights, She, Belief, Luxury, Florida',
#   'emotional': 'Reflection, Longing, Frustration, Desire, Complication',
#   'synopsis': 'The lyrics describe a person reflecting on past experiences, longing for simplicity, and express frustration towards people and situations that complicate their lives. The recurring theme of flashing lights could symbolize the distractions or temptations that hinder personal growth.'},
#  {'track_name': 'Gifted',
#   'artist_name': 'French Montana',
#   'album_name': 'Excuse My French (Deluxe)',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'bitches, real, groupie love, high, money',
#   'emotional': 'love, intoxication, realization, acceptance, desire',
#   'synopsis': 'The lyrics describe a person who receives love and money from others when they are intoxicated. The person feels that they are real and noticeable when they are high and engaging in groupie love.'},
#  {'track_name': "Don't Stop the Music",
#   'artist_name': 'Ed Marquis',
#   'album_name': "Don't Stop the Music",
#   'genres': 'Electro, Dance',
#   'keywords': 'party, dance floor, music, romance, private show',
#   'emotional': 'desire, passion, romance, attraction, intimacy',
#   'synopsis': 'The lyrics describe a late night encounter at a favorite place where the speaker is drawn to someone new, leading to a romantic moment on the dance floor, and a desire to escape with this person into the music.'},
#  {'track_name': "Don't Stop The Music",
#   'artist_name': 'Rihanna',
#   'album_name': 'Good Girl Gone Bad: Reloaded',
#   'genres': 'Pop',
#   'keywords': 'dance floor, music, party, escaping, passion',
#   'emotional': 'attracted, passionate, dancing, impossible, explode',
#   'synopsis': 'The lyrics describe an individual going to a favorite place to dance and party, where they meet someone and are unable to leave due to their attraction. The two engage in a private dance, lost in the music and the moment.'},
#  {'track_name': 'House Of Balloons / Glass Table Girls',
#   'artist_name': 'The Weeknd',
#   'album_name': 'House Of Balloons (Original)',
#   'genres': 'R&B',
#   'keywords': 'Lock me up, Force me, Trade my whole life, I just wanna be, Give me tough love',
#   'emotional': 'Desire for control, Submission, Love and loyalty, Pain and suffering, Passion',
#   'synopsis': "The lyrics express a desire for dominance and control in a relationship, with themes of submission, tough love, and trading one's whole life for it."},
#  {'track_name': 'Faker',
#   'artist_name': 'Elissa',
#   'album_name': 'Select 6 - Music For Our Friends',
#   'genres': 'Electro',
#   'keywords': 'decisions, muse, wasteland, lightning, rainclouds',
#   'emotional': 'emotional turmoil, uncertainty, complicated relationship, emotional baggage, authenticity',
#   'synopsis': "The song expresses the theme of being in a complicated relationship where the speakers are dealing with each other's past mistakes and emotional baggage. They question each other's authenticity and motivation, while acknowledging the emotional turmoil and uncertainty the relationship brings."},
#  {'track_name': 'Mi Primera Cana',
#   'artist_name': 'Diomedes Diaz',
#   'album_name': 'Titulo De Amor',
#   'genres': '',
#   'keywords': 'love, beauty, desire, longing, passion',
#   'emotional': 'love, longing, desire, passion, admiration',
#   'synopsis': "The song expresses the speaker's intense love and longing for a woman, describing her as the most beautiful thing they've ever seen, and their heart belonging to her. The chorus repeats the woman's name, emphasizing the depth of the speaker's feelings."},
#  {'track_name': 'Rahat Ya Khal',
#   'artist_name': 'Autostrad',
#   'album_name': 'Autostrad 2011',
#   'genres': 'Pop',
#   'keywords': 'راحت, قالتلى روح, للناس يشوفونا, ويا ويلاه, وهذا النصيب',
#   'emotional': 'longing, fear, love, desire, understood',
#   'synopsis': 'A person expresses longing and fear of being seen by others, while also expressing love and fear of being loved by them. They write about their desire to be loved despite their fear of being understood.'},
#  {'track_name': 'Eventually',
#   'artist_name': 'Tame Impala',
#   'album_name': 'Currents',
#   'genres': 'Alternative',
#   'keywords': 'breakup, heartache, happiness, last time, eventually',
#   'emotional': 'regret, sadness, happiness, anticipation, hoping',
#   'synopsis': 'A person expresses regret and sadness about ending a relationship, but believes that both parties will ultimately be happier.'},
#  {'track_name': 'Without Me',
#   'artist_name': 'Eminem',
#   'album_name': 'The Eminem Show',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'Obie Trice, Shady, Return, Controversy, Rap',
#   'emotional': 'Return, Controversial, Impact, Emphasis, Express',
#   'synopsis': 'Obie Trice expresses his return to the rap scene, emphasizing his controversial past and his impact on the industry.'},
#  {'track_name': 'TIL FURTHER NOTICE (feat. James Blake & 21 Savage)',
#   'artist_name': 'Travis Scott',
#   'album_name': 'UTOPIA',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'breakup, love, relationship, emotions, introspection',
#   'emotional': 'breakup, regret, reflection, introspection, emotional pain',
#   'synopsis': 'The song expresses the emotions of a person after a breakup, questioning where their ex-partner will go now, and reflecting on past mistakes in the relationship. The lyrics explore themes of love, regret, and introspection.'},
#  {'track_name': 'Numb',
#   'artist_name': 'Linkin Park',
#   'album_name': 'Meteora (Bonus Edition)',
#   'genres': 'Alternative',
#   'keywords': 'feeling faithless, lost, pressure, numb, becoming myself',
#   'emotional': 'faithless, lost, numb, disconnected, wanting to be true to oneself',
#   'synopsis': "The lyrics express feelings of being trapped in someone else's expectations, feeling disconnected, and wanting to become more true to oneself."},
#  {'track_name': 'Twinz (Deep Cover 98) (feat. Fat Joe)',
#   'artist_name': 'Big Pun',
#   'album_name': 'The Legacy: The Best Of Big Pun',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'war, murder, cop-killers, revenge, undercover cop',
#   'emotional': 'revenge, aggression, fear, determination, survival',
#   'synopsis': "The song describes a scene of planned revenge against enemies, involving violent actions and use of weapons, with a strong theme of survival and taking matters into one's own hands."},
#  {'track_name': 'Little Lies',
#   'artist_name': 'ODIE',
#   'album_name': 'Analogue',
#   'genres': 'R&B',
#   'keywords': 'What if, Sins, God, Realize, Sky falling',
#   'emotional': 'Contemplation, Hypothetical situations, Love, Falling, Consequences',
#   'synopsis': 'The lyrics express the theme of contemplating hypothetical situations and the potential consequences, with a recurring imagery of the sky falling and someone falling for someone else.'},
#  {'track_name': 'The World We Knew (Over And Over)',
#   'artist_name': 'Frank Sinatra',
#   'album_name': 'The World We Knew',
#   'genres': 'Jazz',
#   'keywords': 'love, world, memory, dream, gold',
#   'emotional': 'love, memories, magical, dream, loss',
#   'synopsis': 'The lyrics describe the memories of a past love, where the world seemed magical and the sun, moon, and neon signs seemed to be theirs. However, the dream was too much for the other person to hold.'},
#  {'track_name': 'The Final Bell',
#   'artist_name': 'Bill Conti',
#   'album_name': 'Rocky (Original Motion Picture Score)',
#   'genres': 'Films/Games, Film Scores',
#   'keywords': '',
#   'emotional': '',
#   'synopsis': ''},
#  {'track_name': 'No Role Modelz',
#   'artist_name': 'J. Cole',
#   'album_name': '2014 Forest Hills Drive',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'Uncle Phil, Father, L.A., Love, Regret',
#   'emotional': 'Love, Regret, Reflection, Honor, Longing',
#   'synopsis': "The lyrics express the speaker's longing for real love, reflecting on past experiences and regrets, paying homage to influential figures and contrasting shallow women with deeper connections."},
#  {'track_name': 'El Seka Shemal Fe Shemal',
#   'artist_name': 'Cairokee',
#   'album_name': 'Noaata Beida',
#   'genres': 'Pop',
#   'keywords': 'يا ليلي, شمال, الواطي, غالي, مالناش',
#   'emotional': 'longing, desire, persistence, night, presence',
#   'synopsis': 'The speaker longs for the night, expressing desire towards a woman, while also mentioning the presence of thieves and obstacles, with the recurring theme of the night and the persistence of the man.'},
#  {'track_name': 'Koul Chi Aam Yekhlass',
#   'artist_name': 'Magida El Roumi',
#   'album_name': 'Khedni Habibi',
#   'genres': 'Pop',
#   'keywords': '',
#   'emotional': '',
#   'synopsis': ''},
#  {'track_name': 'Let It Happen',
#   'artist_name': 'Tame Impala',
#   'album_name': 'Currents',
#   'genres': 'Alternative',
#   'keywords': 'letting go, running around, voice, whirlwind, moving on',
#   'emotional': 'overwhelmed, letting go, moving on, hope, acceptance',
#   'synopsis': 'The lyrics describe the feeling of being overwhelmed by external noise and internal emotions, but the speaker urges themselves to let go and move on, as if a whirlwind is coming to carry away the old and make way for the new.'},
#  {'track_name': 'Hunnids',
#   'artist_name': 'Sainte',
#   'album_name': 'Local Mvp',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'grinds, get the bags, loot, coupe, crew',
#   'emotional': 'want, get, luxury, desire, lifestyle',
#   'synopsis': 'The lyrics describe a group of people engaging in criminal activities, such as attempting to get money and evade confrontations, while expressing their desire for material possessions and a luxurious lifestyle.'},
#  {'track_name': 'Trojan Horse',
#   'artist_name': 'Dave',
#   'album_name': 'Split Decision',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'feelings, hustle, trap, love, hustling',
#   'emotional': 'feeling villainous, hustling, trauma, trap, love',
#   'synopsis': 'The lyrics express a sense of feeling villainous and trapped, while also describing past experiences of hustling and dealing with difficult situations. The speaker also reflects on past traumas and struggles with love and trust.'},
#  {'track_name': 'Dollhouse',
#   'artist_name': 'The Weeknd',
#   'album_name': 'The Idol Episode 5 Part 2 (Music from the HBO Original Series)',
#   'genres': 'Films/Games, Film Scores',
#   'keywords': 'dollhouse, somewhere, roam free, chokehold',
#   'emotional': 'trapped, controlled, longing, restrained, freedom',
#   'synopsis': 'The lyrics describe a contrast between a past where the speaker is free and in control, and a present where they are restrained and controlled by someone else. The speaker expresses a desire to be in the dollhouse, where they are both perfect and messed up, and can be tortured to sleep. The emotions conveyed include being trapped, controlled, and longing for freedom.'},
#  {'track_name': 'Sprinter',
#   'artist_name': 'Dave',
#   'album_name': 'Sprinter',
#   'genres': 'Rap/Hip Hop',
#   'keywords': "five-star hotel, smokin' cigarette, codeine, Phenergan, Tokyo Drift, millions, whip, diamonds, life, squinting, bae, thick, gin, Skim, Kim, apples, apple cider vinegar, Sprinter, SUV, hundred meters, Irish ferry, Pistol, black card, rap, Tokyo Drift, Yaris, Urus, gyal, two weeks, address, netflix, Amex, platinum, dinner table, manners, t-shirt, napkin, captions, minimal fraction, indigestion, bare snow, Aspen, pain, Aspirin, Maybach music, insults, intelligence, uni, campus, cocaine, students, drumstick, leak, exclusives",
#   'emotional': 'wealth, luxury, pursuit, pleasure, desires',
#   'synopsis': "The song appears to be about a wealthy individual's lifestyle, which includes fast cars, luxury, women, and material possessions. The person in the lyrics speaks about their success and wealth, while also mentioning various experiences and desires. The theme seems to revolve around wealth, luxury, and the pursuit of pleasure."},
#  {'track_name': 'Waka Waka (Esto Es Africa)',
#   'artist_name': 'Shakira',
#   'album_name': 'Sale el Sol',
#   'genres': 'Pop',
#   'keywords': '',
#   'emotional': '',
#   'synopsis': ''},
#  {'track_name': 'could you love me while i hate myself',
#   'artist_name': 'Zeph',
#   'album_name': 'scared of everything',
#   'genres': 'Alternative',
#   'keywords': 'self-hatred, love, deservingness, reciprocity, conditions',
#   'emotional': 'self-hatred, love, vulnerability, uncertainty, hurt',
#   'synopsis': 'A plea for love despite personal inadequacies and inability to reciprocate.'},
#  {'track_name': 'Double Fantasy',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Double Fantasy',
#   'genres': 'R&B',
#   'keywords': "bodies united, trapped in arms, seen what's in heart, knows side of you, can pull out what's inside",
#   'emotional': 'passion, intimacy, desire, hidden emotions, wrong relationship',
#   'synopsis': "The song expresses the passion and intimacy between two individuals, despite the knowledge that their relationship is wrong. The speaker reveals that he is the only one who knows the true side of his lover and can bring out what's hidden within her."},
#  {'track_name': 'Thru My Hair',
#   'artist_name': '¿Téo?',
#   'album_name': '¿Téo?',
#   'genres': 'Rap/Hip Hop, Pop, R&B',
#   'keywords': 'hair, head, city, mood, party',
#   'emotional': 'desire, longing, unable to get over someone, meeting requested, party',
#   'synopsis': "The lyrics express a desire for someone and being unable to get them out of the speaker's mind. The speaker longs for a meeting and references city life and parties."},
#  {'track_name': 'Nails',
#   'artist_name': 'Saint Levant',
#   'album_name': 'Nails',
#   'genres': 'Dance, Pop',
#   'keywords': 'Visa, leader, followed, college, high school',
#   'emotional': 'stressing, followed, insecure, surprised, unexpected',
#   'synopsis': "The lyrics express the artist's stressors in life, including visa issues and being followed by someone, as well as his unexpected role as a leader and the requests for advice and jobs from former acquaintances. The artist also reflects on past bullying over his appearance and nails."},
#  {'track_name': 'NEW MAGIC WAND',
#   'artist_name': 'Tyler, The Creator',
#   'album_name': 'IGOR',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'door, window, photo, joyous, sister',
#   'emotional': "please don't leave, joyous, frustration, desire, fear",
#   'synopsis': 'The lyrics express a desire for change and a plea for someone to stay, while dealing with past relationships and personal struggles.'},
#  {'track_name': 'Matrahak Bi Albi',
#   'artist_name': 'Magida El Roumi',
#   'album_name': 'Khedni Habibi',
#   'genres': 'Pop',
#   'keywords': '',
#   'emotional': '',
#   'synopsis': ''},
#  {'track_name': 'Beghyabek',
#   'artist_name': 'Autostrad',
#   'album_name': 'Beghyabek',
#   'genres': 'Pop',
#   'keywords': '',
#   'emotional': '',
#   'synopsis': ''},
#  {'track_name': 'Alors on danse',
#   'artist_name': 'Stromae',
#   'album_name': 'Cheese',
#   'genres': 'Dance, Pop',
#   'keywords': 'problems, dance, love, work, emotions',
#   'emotional': 'struggle, pray, control, dance, prayers',
#   'synopsis': "The lyrics express the struggle between dealing with problems in life and the desire to escape through dancing and singing. The speaker questions if the issues are worse than death and wonders if it's the music or the problems that take control of their body and mind. They pray for relief but ultimately have to face their problems and keep dancing."},
#  {'track_name': 'Alber',
#   'artist_name': 'Autostrad',
#   'album_name': 'Alber',
#   'genres': 'Pop',
#   'keywords': 'Love, Forgetting, Separation, Memories, Question',
#   'emotional': 'Love, Forgetting, Pain, Separation, Memories',
#   'synopsis': 'Two lovers question each other about forgetting their dreams and the pain of separation, reminding each other of the memories they have shared and the times they have forgotten each other.'},
#  {'track_name': 'BETTER DAYS',
#   'artist_name': 'Rilès',
#   'album_name': 'BETTER DAYS',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'I swear, Living, Quiet thoughts, Walk on my own, Life choices',
#   'emotional': 'Determination, Struggle, Inner conflicts, Emotionally charged, Desire for change',
#   'synopsis': "The lyrics express the speaker's determination to improve their life and overcome struggles, while dealing with inner conflicts and temptations."},
#  {'track_name': 'Cult of Personality (Remastered 2023)',
#   'artist_name': 'Living Colour',
#   'album_name': 'Cult of Personality (Remastered 2023)',
#   'genres': 'Pop',
#   'keywords': 'cult of personality, leader, follow, freedom, identity',
#   'emotional': 'manipulation, control, idolization, aspirations, dependence',
#   'synopsis': "The lyrics express the idea of a powerful figure who exerts control over people through their personality and aspirations. The use of historical figures like Mussolini, Kennedy, Stalin, and Gandhi highlights the manipulative nature of this figure. The chorus repeats the phrase 'cult of personality,' emphasizing the idolization and dependence of the crowd."},
#  {'track_name': 'Come Un Ragazzino',
#   'artist_name': 'Peppino Gagliardi',
#   'album_name': 'I Successi Di Peppino Gagliardi - Come Le Viole',
#   'genres': 'Pop, International Pop',
#   'keywords': 'Return, Spring, Love, Loss, Flowers',
#   'emotional': 'Longing, Loss, Love, Hope, Regret',
#   'synopsis': 'The speaker laments the loss of a loved one and longs for their return, comparing the promise of their return to the blooming of spring and violets.'},
#  {'track_name': 'Glock In My Lap',
#   'artist_name': '21 Savage',
#   'album_name': 'SAVAGE MODE II',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'rappers, guns, money, violence, drugs',
#   'emotional': 'violence, power, aggression, dominance, wealth',
#   'synopsis': 'The lyrics describe a violent and materialistic lifestyle, with references to guns, money, and drugs. The speaker boasts about their wealth, power, and ability to harm opponents.'},
#  {'track_name': 'From the Subway Train',
#   'artist_name': 'Vansire',
#   'album_name': 'Angel Youth',
#   'genres': 'Pop',
#   'keywords': "August, Life, Subway train, Sky's, Driftless zone",
#   'emotional': 'Transient, Passing time, Observations, Unusual, Driftless zone',
#   'synopsis': "The lyrics describe the passing of time during August and the transient nature of life, with observations from the subway train. The speaker finds the sky's colors unusual in this period."},
#  {'track_name': 'Chicago',
#   'artist_name': 'Michael Jackson',
#   'album_name': 'XSCAPE',
#   'genres': 'Pop',
#   'keywords': 'Chicago, meeting, alone, love, lies',
#   'emotional': 'love, surprise, shame, deception, desire',
#   'synopsis': 'The singer met a woman while traveling to Chicago and fell in love with her despite her being married and having children. She tried to keep their relationship a secret, but they continued to meet and lie to their respective partners.'},
#  {'track_name': 'Just A Lil Bit',
#   'artist_name': '50 Cent',
#   'album_name': 'The Massacre',
#   'genres': 'Rap/Hip Hop',
#   'keywords': '50 Cent, G-Unit, club, dancefloor, sex',
#   'emotional': 'desire, pleasure, excitement, confidence, celebration',
#   'synopsis': 'The lyrics describe a night out at the club with 50 Cent and his G-Unit crew. The theme revolves around enjoying the night, dancing, and pursuing sexual encounters.'},
#  {'track_name': 'My Way',
#   'artist_name': 'Frank Sinatra',
#   'album_name': 'My Way (Expanded Edition)',
#   'genres': 'Jazz',
#   'keywords': "final curtain, lived life, did it my way, regrets, man's life",
#   'emotional': 'reflection, acceptance, regret, determination, self-assurance',
#   'synopsis': "The lyrics express a man's reflection on his life, acknowledging his regrets but ultimately accepting that he lived his life on his own terms."},
#  {'track_name': 'Heart To Heart',
#   'artist_name': 'Mac DeMarco',
#   'album_name': 'Here Comes The Cowboy',
#   'genres': 'Alternative',
#   'keywords': "To all the days, together, apart, Heart to heart, each other's lives",
#   'emotional': 'heart to heart, together, apart, significance, past times',
#   'synopsis': 'The lyrics reflect on the past times spent together and apart, emphasizing the significance of being heart to heart throughout.'},
#  {'track_name': 'ALL MINE',
#   'artist_name': 'Brent Faiyaz',
#   'album_name': 'WASTELAND',
#   'genres': 'R&B',
#   'keywords': 'love, relationship, possession, promise, youth',
#   'emotional': 'love, desire, promise, remembrance, commitment',
#   'synopsis': "The song expresses the singer's desire for possession and love in a relationship. They reminisce about past experiences, both good and bad, and promise love and commitment to their partner."},
#  {'track_name': 'Kill Bill',
#   'artist_name': 'SZA',
#   'album_name': 'SOS',
#   'genres': 'R&B',
#   'keywords': 'fan, happy, jealousy, mature, therapist',
#   'emotional': 'jealousy, obsession, hate, love, aloneness',
#   'synopsis': 'The lyrics express feelings of jealousy and obsession towards an ex-partner, despite expressing a desire for maturity and moving on. The speaker contemplates harming their ex and his new partner.'},
#  {'track_name': 'One Dance',
#   'artist_name': 'Drake',
#   'album_name': 'Views',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'Baby, style, dance, Hennessy, one dance',
#   'emotional': 'desire, danger, need, strength, friendship',
#   'synopsis': "The speaker expresses his attraction to someone and the desire for one last dance before leaving, possibly due to dangerous circumstances. He also mentions the need for strength and guidance and making it through safely with friends. There's a reference to a pretty girl and wine."},
#  {'track_name': 'Massive',
#   'artist_name': 'Drake',
#   'album_name': 'Honestly, Nevermind',
#   'genres': 'Dance',
#   'keywords': "I've been alone, Can't fill this void, Losing you, Feelings intertwined, Fighting the urge",
#   'emotional': 'alone, void, losing, feelings, urge',
#   'synopsis': "The lyrics express the speaker's difficulty dealing with the loss of a relationship and their strong feelings towards the other person, as well as their reluctance to let go."},
#  {'track_name': 'P.I.M.P.',
#   'artist_name': '50 Cent',
#   'album_name': "Get Rich Or Die Tryin'",
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'P-I-M-P, money, women, club, luxury',
#   'emotional': 'power, wealth, confidence, attraction, control',
#   'synopsis': 'The song is about a man who identifies himself as a pimp and boasts about his wealth and ability to attract women. He describes the allure of the club scene and the material possessions that attract women, as well as his financial power and control over them.'},
#  {'track_name': 'It Was A Good Day',
#   'artist_name': 'Ice Cube',
#   'album_name': 'Greatest Hits',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'morning, breakfast, day, happiness, gratitude',
#   'emotional': 'happiness, gratitude, surprise, contentment, joy',
#   'synopsis': "The song describes a man's reflection on an unexpected good day filled with small joys, from waking up without problems, playing basketball with friends, to spending time with a woman."},
#  {'track_name': 'En Argentina Nací',
#   'artist_name': 'No sabemos todavia',
#   'album_name': 'Nst en Constantino',
#   'genres': '',
#   'keywords': '',
#   'emotional': '',
#   'synopsis': ''},
#  {'track_name': 'Superhero (Heroes & Villains)',
#   'artist_name': 'Metro Boomin',
#   'album_name': 'HEROES & VILLAINS',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'superhero, dope, money, success, villain',
#   'emotional': 'hero, success, opposition, villain, conflict',
#   'synopsis': 'The song describes the journey of a successful individual who achieved hero status through drugs and wealth, but also faces opposition and the potential of becoming a villain.'},
#  {'track_name': 'Too Many Nights',
#   'artist_name': 'Metro Boomin',
#   'album_name': 'HEROES & VILLAINS',
#   'genres': 'Rap/Hip Hop',
#   'keywords': "keep the bitch jump, money, spend what you want, hit the pole, hittin' the club",
#   'emotional': "hittin' the pole, spend, money, past, can't slow down",
#   'synopsis': "The song lyrics describe a person's experiences of spending money, going to the club, and enjoying the company of women. The main theme seems to be about living life to the fullest and experiencing pleasure and excitement."},
#  {'track_name': 'The Winner Takes It All',
#   'artist_name': 'ABBA',
#   'album_name': 'ABBA Gold',
#   'genres': 'Pop',
#   'keywords': 'winner, loser, game, takes, history',
#   'emotional': 'regret, acceptance, longing, questioning, reflection',
#   'synopsis': "The song describes the idea that one person wins and the other loses in a game or relationship. The singer expresses regret over a past relationship and accepts that it's over. He asks if his ex-partner is moving on and following the rules of the game."},
#  {'track_name': 'Samba de Janeiro',
#   'artist_name': 'Bellini',
#   'album_name': 'Samba de Janeiro',
#   'genres': 'Electro, Dance, Disco',
#   'keywords': 'Samba de Janeiro, Music, Brazil, Dance, Repeating',
#   'emotional': 'Hahaha, Ai, Deus, Joy, Repeating, Excitement',
#   'synopsis': 'This song is about the traditional Brazilian dance, Samba de Janeiro.'},
#  {'track_name': 'Vertigo',
#   'artist_name': 'Khalid',
#   'album_name': 'Suncity',
#   'genres': 'R&B',
#   'keywords': 'believing, ignorance, living, seasons, vertigo',
#   'emotional': 'contemplation, questioning, doubt, uncertainty, perseverance',
#   'synopsis': "The lyrics express the speaker's contemplation on the nature of reality and living, questioning if life is easy or if it's just an illusion. The speaker also ponders their own state of being and their ability to continue in the face of criticism and adversity."},
#  {'track_name': 'Dark Red',
#   'artist_name': 'Steve Lacy',
#   'album_name': "Steve Lacy's Demo",
#   'genres': 'R&B',
#   'keywords': "Something bad, Feelings of impending doom, Fear of abandonment, Longing for someone, Repeating phrase 'only you'",
#   'emotional': 'Fear, Longing, Dread, Desire, Anxiety',
#   'synopsis': "The lyrics express a sense of dread and fear of losing someone, often repeated pleas to not leave, and the belief that the speaker's mind is causing them to dwell on negative thoughts."},
#  {'track_name': "Creepin'",
#   'artist_name': 'Metro Boomin',
#   'album_name': 'HEROES & VILLAINS',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'kissing, heart, truth, playing, creeping',
#   'emotional': 'heart, infidelity, ignorance, struggle, acceptance',
#   'synopsis': "The singer expresses his emotions of discovering his partner's infidelity and his struggle to accept the truth. He expresses a desire to remain ignorant about her past actions and tries to move on."},
#  {'track_name': 'Careless Whisper',
#   'artist_name': 'George Michael',
#   'album_name': 'The Final',
#   'genres': 'Pop',
#   'keywords': 'careless whispers, good friend, dance, ignorance, pain',
#   'emotional': 'regret, sadness, heartache, loss, pain',
#   'synopsis': 'The lyrics express regret and sadness over a lost relationship, where the speaker laments the careless words of a friend that led to heartache and the end of a dance they once shared. The theme explores the idea of missed opportunities and the pain that comes from not knowing when to keep friendship boundaries.'},
#  {'track_name': 'Earth Song',
#   'artist_name': 'Michael Jackson',
#   'album_name': 'HIStory - PAST, PRESENT AND FUTURE - BOOK I',
#   'genres': 'Pop',
#   'keywords': 'sunrise, rain, peace, children, nature',
#   'emotional': 'regret, concern, sadness, harm, loss',
#   'synopsis': 'The lyrics express regret and concern for the state of the world, including war, loss of peace, harm to nature, and the suffering of children.'},
#  {'track_name': 'All The Stars',
#   'artist_name': 'Kendrick Lamar',
#   'album_name': 'All The Stars',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'Love, Talk, Feeling, Dreams, Stars',
#   'emotional': 'Love, Hope, Haunt, Desire, Rejection',
#   'synopsis': 'The song explores the themes of love, dreams, and emotions. The singer questions if love meets their hopes and if past feelings haunt them. They express a desire for truth and a rejection of expectations, entitlement, and false promises. The night is described as a possible moment for self-discovery and the approach of dreams.'},
#  {'track_name': 'Clouded',
#   'artist_name': 'Brent Faiyaz',
#   'album_name': 'Fuck The World',
#   'genres': 'R&B',
#   'keywords': 'sex, texting, desires, relationships, reckless behavior',
#   'emotional': 'desire, infidelity, agitation, confusion, recklessness',
#   'synopsis': 'The lyrics express a theme of sexual desires and reckless behavior in relationships, with mentions of texting and past infidelities.'},
#  {'track_name': "Runnin' Thru the 7th with My Woadies",
#   'artist_name': '$uicideboy$',
#   'album_name': '$outh $ide $uicide',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'house, music, lyrics, rap, French',
#   'emotional': 'home, stop, drugs, violence, disillusionment',
#   'synopsis': 'The lyrics describe a person who invites someone to come home so they can stop an ongoing activity. The lyrics also include references to drugs, violence, and women, as well as a sense of ennui and disillusionment.'},
#  {'track_name': 'Grenade',
#   'artist_name': 'Bruno Mars',
#   'album_name': 'Doo-Wops & Hooligans',
#   'genres': 'Pop',
#   'keywords': 'love, pain, sacrifice,  betrayal, regret',
#   'emotional': 'love, sacrifice, betrayal, pain, regret',
#   'synopsis': "The song describes the speaker's willingness to sacrifice their own wellbeing for a loved one, despite their loved one's lack of reciprocation and eventual betrayal."},
#  {'track_name': 'Amour plastique',
#   'artist_name': 'Videoclub',
#   'album_name': 'Amour plastique',
#   'genres': '',
#   'keywords': 'enloquece, mirada amorosa, alma, piel, bailar',
#   'emotional': 'longing, desire, enchantment, lost, night',
#   'synopsis': "The lyrics describe a person losing themselves in someone's loving gaze, desiring for their soul to be enchanted by the other person's touch. They express a deep longing and desire for the other person, and the nighttime brings thoughts of the beloved. The person expresses a sense of being lost in their own heart's chaos and desires answers to who the other person is and where they are."},
#  {'track_name': 'Questions on My Mind',
#   'artist_name': 'Faraj Suleiman',
#   'album_name': 'Better Than Berlin',
#   'genres': 'Jazz, Rock',
#   'keywords': 'في اسئلة براسي, بعده, شوي, بقولوا, حلوة',
#   'emotional': 'بعده, شوي, بتبكي, حلوة, ودشّرت',
#   'synopsis': "The song describes the speaker's longing for someone named Berlin, reflecting on past experiences and emotions. It also touches upon themes of friendship, change, and the passing of time."},
#  {'track_name': 'Strangers In The Night',
#   'artist_name': 'Frank Sinatra',
#   'album_name': 'Nothing But The Best (2008 Remastered)',
#   'genres': 'Jazz',
#   'keywords': 'strangers, night, love, glance, dance',
#   'emotional': 'love, loneliness, surprise, excitement, passion',
#   'synopsis': 'Two strangers encounter each other and fall in love at first sight during a night out.'},
#  {'track_name': "(I Can't Get No) Satisfaction",
#   'artist_name': 'The Rolling Stones',
#   'album_name': 'Singles 1965-1967',
#   'genres': 'Rock',
#   'keywords': 'dissatisfaction, media: radio, TV, frustration, desire for reaction, travel',
#   'emotional': 'frustration, dissatisfaction, desire, disappointment, longing',
#   'synopsis': "The song expresses the speaker's inability to find satisfaction or fulfillment in various aspects of life, including media, relationships, and personal accomplishments."},
#  {'track_name': 'High Enough',
#   'artist_name': 'K.Flay',
#   'album_name': 'Every Where Is Some Where',
#   'genres': 'Alternative',
#   'keywords': 'love, intoxication, replacement, dependence, desire',
#   'emotional': 'love, desire, dependence, infatuation, relief',
#   'synopsis': "The song expresses the speaker's deep love and dependence on another person, describing them as their source of happiness, inspiration, and relief from the world. The speaker mentions how they no longer need substances like liquor or smoking, as their love is their new source of 'buzz'."},
#  {'track_name': 'Notion',
#   'artist_name': 'The Rare Occasions',
#   'album_name': 'Notion',
#   'genres': 'Alternative, Rock, Indie Rock/Rock pop',
#   'keywords': 'calming notion, perpetual motion, end, death, momentary beam of light',
#   'emotional': 'calming, reality, death, importance, present moment',
#   'synopsis': 'The lyrics express the idea that the notion of living forever may be a calming thought, but the speaker prefers to live in the present and face the reality of death, seeing it as a limit or a window to live or not at all. The speaker questions the value of living forever and the idea of torture after death, and emphasizes the importance of living in the moment.'},
#  {'track_name': 'Moth To A Flame',
#   'artist_name': 'Swedish House Mafia',
#   'album_name': 'Paradise Again',
#   'genres': 'Dance',
#   'keywords': 'moth to a flame, loyalty, relationship, heart, secrets',
#   'emotional': 'love, loyalty, jealousy, longing, secret',
#   'synopsis': "The lyrics describe a speaker drawing someone back into a relationship, despite their current partner being seemingly good for them. The speaker asks if the current partner knows about the speaker's continued connection and the reasons for their loyalty lying with the speaker."},
#  {'track_name': 'Tghayarti',
#   'artist_name': 'El Far3i',
#   'album_name': 'El Rajol El Khashabi',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'change, longing, loss, desire, transition',
#   'emotional': 'longing, regret, desire, change, emotion',
#   'synopsis': "The lyrics describe the speaker's feelings of change and longing for someone who has moved on, expressing regret over lost opportunities and unspoken feelings."},
#  {'track_name': 'Secrets',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Starboy (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'love, secrets, talking in sleep, lies, desires',
#   'emotional': 'love, deceit, secrets, desire, confusion',
#   'synopsis': "The song expresses feelings of love and deceit as the singer reveals they have been listening to their lover's secrets while they sleep, despite being told that they have left their past behind."},
#  {'track_name': 'Ocean Drive',
#   'artist_name': 'Duke Dumont',
#   'album_name': 'Ocean Drive',
#   'genres': 'Dance',
#   'keywords': 'riding, dark night, empty heart, pretending love, storm',
#   'emotional': 'pretending, scared, regret, love, closing storm',
#   'synopsis': 'The lyrics describe a journey through the night with a sense of desperation and pretense, facing a closing storm and dancing with the devil, acknowledging past mistakes and wishing to turn back time.'},
#  {'track_name': 'Paint It, Black',
#   'artist_name': 'The Rolling Stones',
#   'album_name': 'Big Hits (High Tide and Green Grass)',
#   'genres': 'Rock',
#   'keywords': 'painted black, red door, summer clothes, darkness goes, painted black again',
#   'emotional': 'grief, despair, darkness, emptiness, isolation',
#   'synopsis': 'The song expresses a desire for emptiness and darkness, with the speaker wanting to see the world, including himself and a red door, painted black. He sees people and things turning black, and mentions a love that has vanished. The speaker is in a state of grief and wants to hide from the world.'},
#  {'track_name': 'Goodbye Yellow Brick Road',
#   'artist_name': 'Elton John',
#   'album_name': 'Goodbye Yellow Brick Road (Remastered)',
#   'genres': 'Rock',
#   'keywords': 'yellow brick road, go back, plough, penthouse, decided future',
#   'emotional': 'desire, freedom, trapped, longing, simplicity',
#   'synopsis': "The singer expresses a desire to leave his current situation and return to a simpler life, beyond the 'yellow brick road'. He feels trapped and longs for freedom."},
#  {'track_name': 'Imagine',
#   'artist_name': 'John Lennon',
#   'album_name': 'Imagine',
#   'genres': 'Rock',
#   'keywords': 'imagination, no heaven or hell, no countries, no possessions, brotherhood of man',
#   'emotional': 'hope, peace, unity, imagination, dream',
#   'synopsis': 'A call for unity and peace, envisioning a world without boundaries, religions, wars, or possessions.'},
#  {'track_name': 'Hotel California',
#   'artist_name': 'Eagles',
#   'album_name': 'Hotel California (40th Anniversary Expanded Edition)',
#   'genres': 'Rock',
#   'keywords': 'dark desert highway, shimmering light, Heaven or Hell, Hotel California, prisoners',
#   'emotional': 'captivated, trapped, despair, uncertainty, longing',
#   'synopsis': 'The lyrics describe a journey to a mysterious place, possibly Heaven or Hell, called Hotel California. The speaker is drawn to the woman in the doorway and is captivated by the place, but feels trapped and unable to leave.'},
#  {'track_name': '505',
#   'artist_name': 'Arctic Monkeys',
#   'album_name': 'Favourite Worst Nightmare',
#   'genres': 'Alternative',
#   'keywords': 'returning, imagination, flight, drive, waiting, lying, side, thighs, hands, adore, neck, spark, knight, thought, fall, mark, bite, bark, adventure, perfect, place, cry, goodbye, surprise, hands, eyes',
#   'emotional': 'longing, desire, imagination, hope, frustration',
#   'synopsis': "The lyrics express the speaker's longing to return to a place and reconnect with someone, despite the distance or time it takes to get there. The themes of imagination, adoration, and the struggle to maintain a relationship are present."},
#  {'track_name': 'Swimming Pools (Drank)',
#   'artist_name': 'Kendrick Lamar',
#   'album_name': 'Swimming Pools (Drank)',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'drank, swimming pool, liquor, dive, babysit',
#   'emotional': 'drunkenness, encouragement, excess, freedom, nausea',
#   'synopsis': "The lyrics describe a person's experience of drinking and partying, using the metaphor of a swimming pool full of liquor. The person is encouraged to drink more and join in the festivities, but the consequences of excessive drinking are also acknowledged."},
#  {'track_name': 'Praise God',
#   'artist_name': 'Kanye West',
#   'album_name': 'Donda',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'speech, progress, night, serve, praise',
#   'emotional': 'perseverance, faith, hope, encouragement, inspiration',
#   'synopsis': "The lyrics encourage perseverance and faith, urging listeners to keep going even when they feel they're not ready. The speaker emphasizes the importance of following one's word, seeing with new sight, and living and praising God. They also touch on themes of overcoming adversity, forgiveness, and self-improvement."},
#  {'track_name': 'Chamber Of Reflection',
#   'artist_name': 'Mac DeMarco',
#   'album_name': 'Salad Days',
#   'genres': 'Alternative',
#   'keywords': 'alone, rebirth, preparation, men, leaving',
#   'emotional': 'alone, loneliness, preparation, hope, leaving',
#   'synopsis': 'The lyrics express the theme of being alone and preparing for a new beginning, where one will run with better men and be clear among them.'},
#  {'track_name': 'For the First Time',
#   'artist_name': 'Mac DeMarco',
#   'album_name': 'This Old Dog',
#   'genres': 'Alternative',
#   'keywords': 'absence, separation, longing, reunions, emotion',
#   'emotional': 'longing, anticipation, difficulty, reunions, absence',
#   'synopsis': 'The lyrics express the difficulty of being apart from someone and the anticipation of their return, using the metaphor of seeing them for the first time again.'},
#  {'track_name': 'Apocalypse',
#   'artist_name': 'Cigarettes After Sex',
#   'album_name': 'Cigarettes After Sex',
#   'genres': 'Alternative',
#   'keywords': 'cityscapes, crashing helicopters, music, lovers, secrets',
#   'emotional': 'music, longing, memories, unable to move on, haunted',
#   'synopsis': 'The lyrics describe a person who is unable to move on from the past, with images of crumbling cityscapes and helicopters crashing in the ocean. The person is holding onto memories and the music in them, as well as secrets shared with loved ones. They long for their presence and want to be haunted by them.'},
#  {'track_name': 'Cry',
#   'artist_name': 'Cigarettes After Sex',
#   'album_name': 'Cry',
#   'genres': 'Alternative',
#   'keywords': 'love, heart, faithfulness, cry, hurt',
#   'emotional': 'love, hurt, faithfulness, cry, frustration',
#   'synopsis': "The lyrics express the speaker's inability to be faithful in their love, resulting in repeated heartache for their partner."},
#  {'track_name': 'Tone',
#   'artist_name': 'Ruby Haunt',
#   'album_name': 'Sugar',
#   'genres': 'Alternative, Rock, Indie Rock/Rock pop',
#   'keywords': 'red wine, honey, alone, hear you knock, take you back',
#   'emotional': 'hurt, pain, alone, desire, addiction',
#   'synopsis': 'The lyrics describe a complex relationship where the speaker is repeatedly drawn back to someone who causes them pain.'},
#  {'track_name': 'Beggin',
#   'artist_name': 'Madcon',
#   'album_name': 'Beggin',
#   'genres': 'Rap/Hip Hop',
#   'keywords': "begging, love, hand, ridin' high, empty shell",
#   'emotional': 'pleading, love, emptiness, fear, despair',
#   'synopsis': 'The song is about a person pleading for their lover to stay and be with them, expressing the importance of their relationship and the emptiness they feel without it. The speaker acknowledges their past mistakes and the potential for growth, but fears losing their partner and the life they once had.'},
#  {'track_name': 'worldstar money (interlude)',
#   'artist_name': 'Joji',
#   'album_name': 'In Tongues',
#   'genres': 'R&B',
#   'keywords': "I looked at you, Am I crazy?, Watch me burn, Don't hate me, I don't wanna die",
#   'emotional': 'Fear, Questioning self, Emotional turmoil, Burning, Death',
#   'synopsis': 'A person expresses their fear of being perceived as crazy, while also acknowledging their own actions may be questionable. They plead for understanding as they watch themselves succumb to their emotions, ultimately expressing a fear of death.'},
#  {'track_name': 'Lover Is a Day',
#   'artist_name': 'Cuco',
#   'album_name': 'wannabewithu',
#   'genres': 'Rock, Rock & Roll/Rockabilly',
#   'keywords': 'Time changed, My mind, Love, Different, Furthering distance',
#   'emotional': 'Love, Conflict, Imperfections, Understanding, Memories',
#   'synopsis': "The lyrics express the speaker's internal conflict of being unable to forget their lover, while being aware of the changes in themselves and in their relationship. They also acknowledge their imperfections and ask for the lover's acceptance and understanding."},
#  {'track_name': 'Ordinary Life',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Starboy (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'Heaven, Hell, Life, Death, Extraordinary',
#   'emotional': 'Intense, Living, Death, Unconventional, Experience',
#   'synopsis': 'The lyrics express a sense of living an unconventional life, with references to death, heaven, and hell. The speaker describes intense experiences, including the feeling of dying and the presence of a devil and a halo.'},
#  {'track_name': 'Low Life (feat. The Weeknd)',
#   'artist_name': 'Future',
#   'album_name': 'EVOL',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'getting high, molly, Follies, Ferraris, Lambs',
#   'emotional': 'getting high, wealth, promiscuity, bragging, representation',
#   'synopsis': 'The lyrics describe a person getting high and engaging in promiscuous behavior, bragging about wealth and possessions, and representing for the low life.'},
#  {'track_name': 'Professional',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Kiss Land (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'somebody, happiness, love, professional, sophisticated',
#   'emotional': 'happiness, struggles, strength, self-discovery, independence',
#   'synopsis': 'The lyrics express the theme of personal growth and self-discovery through experiences and relationships. The speaker reflects on past struggles and how they have made them stronger, and the value of self-worth and independence.'},
#  {'track_name': 'Sacrifice',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Dawn FM',
#   'genres': 'R&B',
#   'keywords': 'summer, club, living, dreams, people',
#   'emotional': 'control, losing, passion, living, love',
#   'synopsis': "The song expresses the speaker's passion for living life to the fullest and enjoying the company of loved ones, despite facing challenges and obstacles."},
#  {'track_name': 'Pretty',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Kiss Land (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'love, return, reconciliation, absence, hope',
#   'emotional': 'love, pain, hope, anticipation, fear',
#   'synopsis': "The song describes a long separation between two lovers, the pain and fear of infidelity, and the hope and anticipation of being reunited and feeling loved and beautiful in each other's arms."},
#  {'track_name': 'Nothing Without You',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Starboy (Deluxe)',
#   'genres': 'R&B',
# ...
#  {'track_name': 'Infinity',
#   'artist_name': 'Jaymes Young',
#   'album_name': 'Feel Something',
#   'genres': 'Alternative',
#   'keywords': 'love, infinity, soul, passion, commitment',
#   'emotional': 'love, passion, intensity, commitment, infatuation',
#   'synopsis': "The song expresses the depth and intensity of the speaker's love for someone, describing it as eternal and beyond control. They have lost themselves in this love and are willing to make sacrifices for it."},
#  {'track_name': 'Arcade',
#   'artist_name': 'Duncan Laurence',
#   'album_name': 'Arcade',
#   'genres': 'Pop',
#   'keywords': 'broken heart, cracks, losing game, love, carry on',
#   'emotional': 'broken-hearted, pain, losing, carry on, addicted',
#   'synopsis': 'The lyrics express the theme of a failed love, with the speaker feeling broken-hearted and stuck in a losing game. They have lost pieces of themselves in the relationship and now carry on despite the pain.'},
#  {'track_name': 'Maps',
#   'artist_name': 'Maroon 5',
#   'album_name': 'V',
#   'genres': 'Pop',
#   'keywords': 'longing, searching, map, following, wonder',
#   'emotional': 'longing, wonder, regret, disappointment, quest',
#   'synopsis': "The lyrics express the speaker's longing for a past relationship and their attempts to find their way back to that person. They question the absent partner's actions during difficult times and lament their own falls and mistakes."},
#  {'track_name': 'Sugar',
#   'artist_name': 'System of A Down',
#   'album_name': 'System Of A Down',
#   'genres': 'Rock, Hard Rock, Metal',
#   'keywords': 'Kombucha mushroom people, Sugar, Life, Call it insane, Desolate room',
#   'emotional': 'anger, disconnected, self-destructive, desire, frustration',
#   'synopsis': "The lyrics describe a person who feels trapped and disconnected from the world, engaging in self-destructive behaviors and expressing anger towards others. The repeated use of the word 'sugar' may be a metaphor for something sweet and desirable, but ultimately empty or harmful."},
#  {'track_name': 'Demons',
#   'artist_name': 'Imagine Dragons',
#   'album_name': 'Night Visions',
#   'genres': 'Alternative',
#   'keywords': 'cold days, saints, dreams failing, blood, demons',
#   'emotional': 'despair, inner demons, failure, deception, unprotected',
#   'synopsis': "The lyrics express feelings of despair and the presence of inner demons when dreams fail, and the speaker's inability to hide the truth or protect the one they care about."},
#  {'track_name': 'Natural',
#   'artist_name': 'Imagine Dragons',
#   'album_name': 'Origins (Deluxe)',
#   'genres': 'Alternative',
#   'keywords': 'Will you hold the line, House, Consequence, Stars align, Natural',
#   'emotional': 'Determination, Questioning, Challenges, Cost, Success',
#   'synopsis': 'The lyrics express the idea that making it in the world requires being cold and ruthless, with the recurring theme of natural selection and the cost of success. The speaker is facing challenges and is questioning the consequences of his actions, while also expressing a sense of determination to make it through.'},
#  {'track_name': 'Lying from You',
#   'artist_name': 'Linkin Park',
#   'album_name': 'Meteora',
#   'genres': 'Alternative',
#   'keywords': 'pretend, identity, truth, bend, lying',
#   'emotional': 'desire, deception, escape, acceptance, flaws',
#   'synopsis': "The lyrics express the theme of deceit and the desire to escape one's past and be accepted for who they truly are, despite their flaws."},
#  {'track_name': 'INDUSTRY BABY',
#   'artist_name': 'Lil Nas X',
#   'album_name': 'INDUSTRY BABY',
#   'genres': 'Rap/Hip Hop, Pop',
#   'keywords': 'D-Daytrip, Grammys, Plaques, Champions, Top',
#   'emotional': 'Success, Determination, Confidence, Challenges, Achievement',
#   'synopsis': "The lyrics describe the artist's success and determination to continue rising in the music industry despite challenges and opposition. They express the artist's confidence and boast about their accomplishments, while also acknowledging past doubts and adversity."},
#  {'track_name': "Gangsta's Paradise",
#   'artist_name': 'Coolio',
#   'album_name': "Gangsta's Paradise",
#   'genres': 'Rap/Hip Hop, R&B',
#   'keywords': "valley of the shadow of death, gangsta's paradise, livin', violence, hood",
#   'emotional': 'life and realize, mind gone, lined in chalk, anger, death',
#   'synopsis': "The song describes a life spent in the gangsta's paradise, where violence and survival are the norm. The speaker reflects on his past actions and the consequences they may have, including the potential for an early death."},
#  {'track_name': 'Animals',
#   'artist_name': 'Maroon 5',
#   'album_name': 'Animals',
#   'genres': 'Pop',
#   'keywords': 'animals, hunt, scent, preying, hide',
#   'emotional': 'obsession, desire, passion, infatuation, intensity',
#   'synopsis': 'The lyrics describe a passionate and all-consuming relationship where one partner is obsessed with the other and cannot resist their attraction, despite any attempts at hiding or running away.'},
#  {'track_name': 'Wake Up, Get Up, Get Out There',
#   'artist_name': 'Lyn Inaizumi',
#   'album_name': 'PERSONA5 ORIGINAL SOUNDTRACK',
#   'genres': 'Films/Games, Film Scores',
#   'keywords': 'dream, love, life, seeing, falling',
#   'emotional': 'longing, regret, desire, loss, dream',
#   'synopsis': "The lyrics describe the speaker's experiences in a dream-like state, filled with longing and regret for a lost love. They express the desire to go back to a previous moment and make things right, as well as the feeling of life flashing before their eyes."},
#  {'track_name': 'Beneath the Mask',
#   'artist_name': 'Lyn Inaizumi',
#   'album_name': 'PERSONA5 ORIGINAL SOUNDTRACK',
#   'genres': 'Films/Games, Film Scores',
#   'keywords': 'shapeshifter, mask, hiding, twilight, masquerade',
#   'emotional': 'hiding, dark, sad, searching, revealing',
#   'synopsis': "The lyrics express the theme of hiding one's true self and identity, possibly in search of answers or to avoid revealing 'dark' or 'sad' truths. The speaker identifies as a shapeshifter, using masks to conceal their face and mind."},
#  {'track_name': 'Heartbeat, Heartbreak',
#   'artist_name': '平田志穂子',
#   'album_name': 'ペルソナ4 オリジナル・サウンドトラック',
#   'genres': 'Films/Games, Film Scores',
#   'keywords': 'heartbeat, heartbreak, promise, ache, dream',
#   'emotional': 'pain, longing, heartbreak, aching, frustration',
#   'synopsis': 'The lyrics express the pain and longing of a broken promise, with the recurring themes of heartbeats and heartbreaks.'},
#  {'track_name': 'Throw Away Your Mask',
#   'artist_name': 'Lyn Inaizumi',
#   'album_name': 'Persona 5 Royal: Original Soundtrack',
#   'genres': 'Films/Games, Film Scores',
#   'keywords': 'beliefs, faith, dreams, suffering, guidance',
#   'emotional': 'faith, encouragement, freedom, belief, potential',
#   'synopsis': 'The lyrics encourage the listener to have faith in their beliefs, let go of suffering, and believe in the potential of their dreams coming true. They also emphasize the importance of guidance from above and being free from pretenses.'},
#  {'track_name': 'drivers license',
#   'artist_name': 'Olivia Rodrigo',
#   'album_name': 'SOUR',
#   'genres': 'Pop',
#   'keywords': "driver's license, ex-partner, suburbs, heartbreak, love",
#   'emotional': 'heartbreak, longing,  regret,  sadness, love',
#   'synopsis': "The singer reflects on driving past their ex-partner's house after getting their driver's license, feeling heartbroken over the end of their relationship and struggling to move on."},
#  {'track_name': 'Fairytale',
#   'artist_name': 'Alexander Rybak',
#   'album_name': 'Fairytale',
#   'genres': 'Pop',
#   'keywords': 'younger, girl, sweethearts, fairytale, love',
#   'emotional': 'love, heartache, past, pursuit, longing',
#   'synopsis': 'The lyrics describe past and present feelings of love and heartache for a woman who was once a sweetheart but is now lost. The speaker expresses a longing for the past and an acceptance of pain in the pursuit of love.'},
#  {'track_name': "Don't Stop Believin'",
#   'artist_name': 'Journey',
#   'album_name': 'The Essential Journey',
#   'genres': 'Rock',
#   'keywords': "small-town girl, city boy, midnight train, goin' anywhere, strangers waiting",
#   'emotional': 'lonely, seeking emotion, hiding, paying anything, believing',
#   'synopsis': 'Two individuals, one from a small town and the other from a city, seek excitement and emotion in their lives through various means.'},
#  {'track_name': 'Bad Habits',
#   'artist_name': 'Ed Sheeran',
#   'album_name': 'Bad Habits',
#   'genres': 'Pop',
#   'keywords': 'bad habits, control, paradise, late nights, stranger',
#   'emotional': 'control, implode, lose control, escaping, alone',
#   'synopsis': "The lyrics describe a cycle of repeating actions leading to late nights alone with strangers, and the speaker's inability to resist, despite knowing the potential negative consequences."},
#  {'track_name': 'Borderline',
#   'artist_name': 'Tame Impala',
#   'album_name': 'The Slow Rush',
#   'genres': 'Alternative',
#   'keywords': 'borderline, pain and rapture, sober up, known and loved, time',
#   'emotional': 'borderline, pain, rapture, sober, loved',
#   'synopsis': 'The lyrics express a sense of being on the edge, between pain and pleasure, and the passage of time. The singer questions if they will be known and loved, and wonders about trust and sobriety.'},
#  {'track_name': 'Watermelon Sugar',
#   'artist_name': 'Harry Styles',
#   'album_name': 'Fine Line',
#   'genres': 'Pop',
#   'keywords': 'summer, berries, strawberries, song, feeling',
#   'emotional': 'craving, attachment, desire, summer, feeling',
#   'synopsis': 'The song describes the desire for the taste and feeling of summer, specifically through the metaphors of strawberries and watermelon. The speaker expresses a strong craving and attachment to these sensations.'},
#  {'track_name': 'Shivers',
#   'artist_name': 'Ed Sheeran',
#   'album_name': '=',
#   'genres': 'Pop',
#   'keywords': 'arrow, heart, kiss, love, shivers',
#   'emotional': 'love, desire, intense feelings, shivers, passion',
#   'synopsis': "The lyrics express the intense feelings of love and desire, with references to kissing, dancing, and being unable to get enough of the person's presence."},
#  {'track_name': 'Ms. Jackson',
#   'artist_name': 'OutKast',
#   'album_name': 'Stankonia',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'love, relationship, feelings, questioning, dance',
#   'emotional': 'confusion, uncertainty, desire, questioning, dance',
#   'synopsis': "The lyrics express the speaker's confusion and uncertainty in a relationship, questioning their partner's feelings and their own, while also acknowledging the desire to dance and be happy."},
#  {'track_name': 'No Lie',
#   'artist_name': 'Sean Paul',
#   'album_name': 'No Lie',
#   'genres': 'Reggae',
#   'keywords': 'Feel your eyes, Take control, Get the vibe, Hypnotic move, Gyal, we never miss',
#   'emotional': 'Desire, Control, Attraction, Hypnotic, Excitement',
#   'synopsis': "The lyrics express a desire for control, attraction, and the hypnotic effect of someone's movements. The speakers invite the listener to join them in an exciting, lit night."},
#  {'track_name': 'In Bloom',
#   'artist_name': 'Nirvana',
#   'album_name': 'Nevermind (Super Deluxe Edition)',
#   'genres': 'Rock',
#   'keywords': 'sell the kids, reproductive glands, shoot his gun, pretty songs, nature is a whore',
#   'emotional': 'sell the kids, knows not what it means, nature is a whore, shoot his gun, tender age in bloom',
#   'synopsis': "The lyrics describe a person who enjoys singing songs and shooting a gun, but doesn't understand their meaning. The lyrics also mention selling children, changing weather, and nature being described as a whore. There's also a reference to reproductive glands and bruises on fruit, suggesting a connection to the natural world and its cycles."},
#  {'track_name': 'Heartless',
#   'artist_name': 'Kanye West',
#   'album_name': '808s & Heartbreak',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'night, talk, road, lost soul, heartless',
#   'emotional': 'heartbreak, frustration, confidence, misunderstanding, desire',
#   'synopsis': 'The speaker reflects on a past heartbreak and the heartlessness of the woman involved. They argue and discuss their past actions and the misunderstandings between them. The speaker expresses frustration and confidence in themselves, implying a desire for reconciliation but also a sense of moving on.'},
#  {'track_name': 'The Trooper',
#   'artist_name': 'Iron Maiden',
#   'album_name': 'Ed Hunter',
#   'genres': 'Rock',
#   'keywords': 'battlefield, war, death, fighting, combat',
#   'emotional': 'fear, pain, grief, isolation, defiance',
#   'synopsis': 'The lyrics describe the experience of being in a war, with the repeated theme of engaging in battle, facing death, and the senseless loss of life.'},
#  {'track_name': 'أحلف بالليالى',
#   'artist_name': 'Amr Diab',
#   'album_name': 'ويلمونى',
#   'genres': '',
#   'keywords': 'night, promise, love, forget, feelings',
#   'emotional': 'love, past, forget, present, feelings',
#   'synopsis': 'The lyrics describe a promise made under the night sky to a loved one, forgetting past stories and focusing on the present feelings and love.'},
#  {'track_name': 'Koll Li Lamouni',
#   'artist_name': 'Zekra',
#   'album_name': 'Al Asami',
#   'genres': '',
#   'keywords': '',
#   'emotional': '',
#   'synopsis': ''},
#  {'track_name': 'Fouq annakhl',
#   'artist_name': 'Sabah Fakhry',
#   'album_name': "Rawae'a Sabah Fakhri",
#   'genres': '',
#   'keywords': '',
#   'emotional': '',
#   'synopsis': ''},
#  {'track_name': "Jeet Bewa'atek",
#   'artist_name': 'Melhem Barakat',
#   'album_name': 'Ahla Zhohour',
#   'genres': '',
#   'keywords': '',
#   'emotional': '',
#   'synopsis': ''},
#  {'track_name': 'Walk It Talk It',
#   'artist_name': 'Migos',
#   'album_name': 'Culture II',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'Walk it like I talk it, big talks, chain, dope, respect',
#   'emotional': 'confidence, wealth, success, contrast, boasts',
#   'synopsis': "The lyrics express confidence, wealth, and success through the metaphor of 'walking it like they talk it'. The artists mention their possessions, business dealings, and achievements. There is a theme of contrasting appearances and reality."},
#  {'track_name': 'Riot',
#   'artist_name': 'XXXTENTACION',
#   'album_name': 'Riot',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'violence, racism, murder, ignorance, prejudice',
#   'emotional': 'violence, aggression, frustration, hatred, despair',
#   'synopsis': 'The lyrics express themes of violence, racism, and prejudice, with the speaker advocating for peace but also justifying violence and murder. The song explores the cycle of violence and the impact on innocent people.'},
#  {'track_name': 'After Party',
#   'artist_name': 'Don Toliver',
#   'album_name': 'Heaven Or Hell',
#   'genres': 'Rap/Hip Hop',
#   'keywords': "after party, sipping, Henn' and Bacardi, pull up, friends",
#   'emotional': "trippin', dizzy, burning up, calm nerves, getting high",
#   'synopsis': 'The lyrics describe a person attending an after party, consuming alcohol and enjoying themselves with friends.'},
#  {'track_name': 'No More What Ifs',
#   'artist_name': 'Lyn Inaizumi',
#   'album_name': 'Persona 5 Royal: Original Soundtrack',
#   'genres': 'Films/Games, Film Scores',
#   'keywords': 'People, Come and go, Alone, Thinking, Life',
#   'emotional': 'Alone, Thinking, Fear, Proud, Passionate',
#   'synopsis': 'The lyrics express the idea of being alone and reflecting on past choices and experiences, with a focus on accepting oneself and living life passionately.'},
#  {'track_name': 'Out of Time',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Dawn FM',
#   'genres': 'R&B',
#   'keywords': 'trauma, regret, love, time, healing',
#   'emotional': 'regret, love, trauma, lost, longing',
#   'synopsis': 'The lyrics express regret for past actions leading to a lost love and the inability to win back that love, despite expressing love and care in the present.'}]

# %%
from nomic import atlas
import numpy as np
dataset = atlas.map_data(data = metadatas, 
                         embeddings=np.array([emb[1] for emb in embeddings]), 
                         identifier="grad_playlist_lyrics_metadata")
# Out:
# 2024-03-19 23:21:24.969 | WARNING  | nomic.atlas:map_data:96 - An ID field was not specified in your data so one was generated for you in insertion order.
# 2024-03-19 23:21:29.252 | INFO     | nomic.dataset:_create_project:868 - Creating dataset `grad-playlist-lyrics-metadata`
# 2024-03-19 23:21:29.799 | INFO     | nomic.atlas:map_data:108 - Uploading data to Atlas.
# 1it [00:02,  2.05s/it]
# 2024-03-19 23:21:31.877 | INFO     | nomic.dataset:_add_data:1537 - Upload succeeded.
# 2024-03-19 23:21:31.881 | INFO     | nomic.atlas:map_data:123 - `tyqnology/grad-playlist-lyrics-metadata`: Data upload succeeded to dataset`
# 2024-03-19 23:21:32.532 | WARNING  | nomic.dataset:create_index:1116 - You did not specify the `topic_label_field` option in your topic_model, your dataset will not contain auto-labeled topics.
# 2024-03-19 23:21:34.180 | INFO     | nomic.dataset:create_index:1246 - Created map `grad_playlist_lyrics_metadata` in dataset `tyqnology/grad-playlist-lyrics-metadata`: https://atlas.nomic.ai/data/tyqnology/grad-playlist-lyrics-metadata/map
