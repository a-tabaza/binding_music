# %%
import json
import requests
import numpy as np
import tempfile
import os
from tqdm import tqdm

# %%
tracks = json.load(open('/workspace/fairouz/fairouz_conf/fairouz/tracks_contextualized.json'))

# %%
def embed_lyrics(lyric, emb_dim = 1024):
    if lyric["lyrics"] == "":
        return np.zeros(emb_dim)
    
    url = "https://w7852kszrbkrz2-4000.proxy.runpod.net/embed/"
    lyrics = {
        "lyrics_summary": lyric["summary"],
        "lexical_keywords": lyric["context"],
        "sentiment_keywords": lyric["emotional"]
    }
    headers = {
        'Content-Type': 'application/json',
        'Authorization': 'Bearer 543c7086-c880-45de-8bce-6c9c906293bb'
        }
    response = requests.post(url, json=lyrics, headers=headers)
    return np.array(json.loads(response.json())["embedding"])

# %%
embeddings = []

# %%
for id, track in tqdm(tracks.items(), total=len(tracks.keys())):
    try:
        embeddings.append((id, embed_lyrics(track["lyrics"])))
    except Exception as e:
        print(e)

assert len(embeddings) == len(tracks.keys())
# Out:
# 100%|██████████| 822/822 [03:20<00:00,  4.09it/s]

# %%
embeddings_json = [{"id": id, "embedding": embedding.tolist()} for id, embedding in embeddings]

# %%
json.dump(embeddings_json, open("/workspace/fairouz/fairouz_conf/fairouz/embeddings/lyrics/song_lyrics_e5_embeddings.json", "w"))

# %%
metadatas = []

# %%
for emb in embeddings_json:
    md = tracks[emb["id"]]
    md_new = {
        "track_name": md["track_title"],
        "artist_name": md["artist_name"],
        "album_name": md["album_name"],
        "genres": ", ".join(md["genres"]),
        "keywords": ", ".join(md["lyrics"]["context"]),
        "emotional": ", ".join(md["lyrics"]["emotional"]),
        "synopsis": md["lyrics"]["summary"]
    }
    metadatas.append(md_new)

# %%
np.array([emb[1] for emb in embeddings]).shape
# Out:
# (822, 1024)

# %%
len(metadatas)
# Out:
# 822

# %%
metadatas
# Out:
# [{'track_name': 'True Colors',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Starboy (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'new lover, trust, true colors, past relationships, painting a picture',
#   'emotional': 'desire for transparency, confusion, trust issues, longing, hopefulness',
#   'synopsis': "The song is about a new relationship and the importance of trust and honesty in it. The singer asks the lover to reveal their true colors and past experiences, and expresses confusion about inconsistencies in their stories. The chorus repeats the phrase 'paint me a picture with your true colors' and 'these are confessions of a new lover', indicating the desire for transparency and understanding in the relationship."},
#  {'track_name': 'Nothing Without You',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Starboy (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'belong, darkness, love, pain, nothing',
#   'emotional': 'love, dependence, emptiness, pain, fear',
#   'synopsis': "The lyrics express the speaker's deep emotional dependence on someone, describing the feeling of emptiness and pain when apart from them. The speaker confesses their fear of losing this person and their fear of being without them."},
#  {'track_name': 'Secrets',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Starboy (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'love, secrets, talking in sleep, lies, deception',
#   'emotional': 'betrayal, disappointment, doubt, suspicion, frustration',
#   'synopsis': "The song expresses the speaker's discovery of their partner's lies and hidden desires through their talking in their sleep. The speaker feels betrayed and realizes they are not the only one in their partner's affections."},
#  {'track_name': 'Stargirl Interlude',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Starboy (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'vision, kitchen, scratching, counter tops, stargirl',
#   'emotional': 'intense emotion, abusive relationship, paradoxical feeling, loving the pain, stargirl',
#   'synopsis': "The lyrics describe a woman's intense emotional response to being in an abusive relationship, expressing a paradoxical feeling of loving the pain inflicted upon her. She urges her partner, referred to as 'starboy', to shine and be a 'stargirl'."},
#  {'track_name': 'A Lonely Night',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Starboy (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'apart, lonely night, love, decision, together',
#   'emotional': 'regret, love, apology, togetherness, loneliness',
#   'synopsis': 'The lyrics express the idea that the speakers are better off being apart from each other, describing a past love and a regretful decision to be together. The theme revolves around the theme of love and the idea that some things are better left apart.'},
#  {'track_name': 'Party Monster',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Starboy (Deluxe)',
#   'genres': 'R&B',
#   'keywords': "I'm good, Girl, Understand, Drank, Paranoid",
#   'emotional': 'Desire, Confidence, Paranoia, Longing, Reflection',
#   'synopsis': "The lyrics describe a person expressing their confidence and desiring a companion who truly understands them. They mention past experiences, including seeing a woman dancing and drinking, and the desire for that woman's attention. The song also features themes of paranoia and having women around, possibly causing distractions or trouble."},
#  {'track_name': 'All I Know',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Starboy (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'stigma, doubt, heartbreak, lovemaking, money',
#   'emotional': 'determination, desire, boastfulness, confidence, vulnerability',
#   'synopsis': "The lyrics express the speaker's determination to win over a woman's trust and love, despite past misconceptions and doubts. The speaker also boasts about their wealth and past sexual conquests."},
#  {'track_name': 'Starboy',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Starboy (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'mood, tease, money, style, pain',
#   'emotional': 'boastful, teasing, wealth, alleviate, pain',
#   'synopsis': 'The lyrics describe a boastful individual who tries to put others in a bad mood and taunt them with his wealth and possessions. He switches up his style and uses his wealth to alleviate pain.'},
#  {'track_name': 'Attention',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Starboy (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'attention, love, relationship, desire, trust',
#   'emotional': 'longing, hesitation, confusion, doubt, desire',
#   'synopsis': "The lyrics express the speaker's confusion and longing in a past relationship, with the recurring theme of the other person's need for attention and the speaker's doubt and hesitation."},
#  {'track_name': 'Six Feet Under',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Starboy (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'money, power, independence, lifestyle, paper',
#   'emotional': 'independence, focused, wealth, extravagant, lifestyle',
#   'synopsis': "The lyrics describe a woman who doesn't depend on anyone, values her independence, and is focused on accumulating wealth and living an extravagant lifestyle. She is not interested in love or family and is willing to do whatever it takes to get what she wants."},
#  {'track_name': 'Love To Lay',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Starboy (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'desire, questions, relationship, emotional_confusion, intimacy',
#   'emotional': 'desire, confusion, longing, intimacy, emotional_connection',
#   'synopsis': "The lyrics express the speaker's desire for a relationship, filled with intimacy and emotional connection. However, there is confusion and a longing for answers regarding the other person's feelings and past actions."},
#  {'track_name': 'Sidewalks',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Starboy (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'Sidewalks, Life, Struggle, Success, Emotions',
#   'emotional': 'Resilience, Ambition, Turmoil, Success, Emotional expression',
#   'synopsis': "The song lyrics describe an individual's journey from poverty to success, with the metaphor of sidewalks representing the constant presence and guidance throughout their life. The lyrics express themes of resilience, ambition, and emotional turmoil."},
#  {'track_name': 'Ordinary Life',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Starboy (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'Heaven, Hell, Life, Death, Ordinary',
#   'emotional': 'Passion, Recklessness, Acceptance, Life, Death',
#   'synopsis': 'The lyrics describe a life that is not ordinary, filled with passion, recklessness, and the acceptance of death.'},
#  {'track_name': 'Oddam El Nas',
#   'artist_name': 'Mohamed Hamaki',
#   'album_name': 'Kol Youm Men Dah',
#   'genres': 'Pop',
#   'keywords': 'life, love, you, living, together',
#   'emotional': 'love, longing, desire, togetherness, focus',
#   'synopsis': "The lyrics describe the speaker's longing to live their life with someone they love, leaving their past behind and focusing solely on their relationship."},
#  {'track_name': 'Radeeny',
#   'artist_name': 'Mohamed Hamaki',
#   'album_name': 'Kol Youm Men Dah',
#   'genres': 'Pop',
#   'keywords': 'Saturday, love, hope, drinking, promise',
#   'emotional': 'love, hope, sadness, longing, desire',
#   'synopsis': "The lyrics describe the speaker's actions during a Saturday night, including calculating bills, paying for drinks, and dealing with their sadness. They express their love and hope for a promise with someone, possibly an unrequited love."},
#  {'track_name': 'Yzalzel',
#   'artist_name': 'Mohamed Hamaki',
#   'album_name': 'Kol Youm Men Dah',
#   'genres': 'Pop',
#   'keywords': 'hear, said, repeat, wait, love',
#   'emotional': 'longing, desire, captivation, unattainable, waiting',
#   'synopsis': 'The lyrics describe someone who hears someone or something that keeps repeating and captivates them, despite their inability to live up to or reach their expectations or desires. The theme is one of longing and unattainability.'},
#  {'track_name': 'Ya Sattar',
#   'artist_name': 'Mohamed Hamaki',
#   'album_name': 'Kol Youm Men Dah',
#   'genres': 'Pop',
#   'keywords': 'Star, Eyes, Love, Heart, Desire',
#   'emotional': 'Longing, Desire, Inability to let go, Determination, Attraction',
#   'synopsis': "The lyrics express the speaker's deep longing and inability to be without the person referred to as a 'Star'. They describe the allure of the person's presence and the speaker's determination to keep them close."},
#  {'track_name': 'Mel Bedaya',
#   'artist_name': 'Mohamed Hamaki',
#   'album_name': 'Kol Youm Men Dah',
#   'genres': 'Pop',
#   'keywords': 'love, pain, life, hope, time',
#   'emotional': 'regret, hurt, desire, time, pain',
#   'synopsis': "The lyrics express the speaker's regret of letting go of their love due to past hurts and pain, expressing a desire to turn back time and change their actions. The theme revolves around love, pain, and the passing of time."},
#  {'track_name': 'From The Pinnacle To The Pit',
#   'artist_name': 'Ghost',
#   'album_name': 'Meliora (Deluxe Edition)',
#   'genres': 'Metal',
#   'keywords': 'crown, empire, heavens, independence, pinnacle',
#   'emotional': 'power, falling, grace, cast_out, independence',
#   'synopsis': 'The lyrics describe the concept of power and falling from grace, using imagery of crowns, empires, and the pinnacle and pit. The speaker goes from wearing a crown and wielding power to being cast out of the heavens and ending up on the ground.'},
#  {'track_name': 'Majesty',
#   'artist_name': 'Ghost',
#   'album_name': 'Meliora (Deluxe Edition)',
#   'genres': 'Metal',
#   'keywords': 'higher power, seraph skies, chaos, sinners, old one',
#   'emotional': 'despair, beauty, power, sinners, surrounded',
#   'synopsis': 'The lyrics describe a higher power or old one, who is surrounded by chaos and sinners seeking his power. The speaker acknowledges the beauty within this old one, despite the surrounding despair and rot.'},
#  {'track_name': 'Cirice',
#   'artist_name': 'Ghost',
#   'album_name': 'Meliora (Deluxe Edition)',
#   'genres': 'Metal',
#   'keywords': 'presence, darkness, rumble, thunder, scars',
#   'emotional': 'longing, connection, emotions, thunder, scars',
#   'synopsis': 'The song expresses a deep connection and longing between two people, using the metaphor of thunder and scars to describe the emotions within. The singer urges the listener to acknowledge their feelings and the importance of their connection.'},
#  {'track_name': 'Deus In Absentia',
#   'artist_name': 'Ghost',
#   'album_name': 'Meliora (Deluxe Edition)',
#   'genres': 'Metal',
#   'keywords': 'exploration, dark and light, urban night, funeral pyre, eternally tied',
#   'emotional': 'commitment, connection, hardship, darkness, deep emotion',
#   'synopsis': 'The lyrics express a theme of being tied to someone or something, even in times of hardship and darkness. The world is described as being on fire, and the speakers are there to stay and burn together, suggesting a deep connection or commitment.'},
#  {'track_name': 'Mummy Dust',
#   'artist_name': 'Ghost',
#   'album_name': 'Meliora (Deluxe Edition)',
#   'genres': 'Metal',
#   'keywords': 'corruption, greed, opulence, riches, mummy dust',
#   'emotional': 'greed, corruption, mirth, riches, sordid',
#   'synopsis': "The lyrics describe a speaker who carries an individual on a wolf's back to corrupt humanity with opulence, greed, and riches. The individual is referred to as a 'possesseé of avarice' and 'ruler of the earth.' The speaker intends to smother the individual in riches till they choke on sordid mirth."},
#  {'track_name': 'Spirit',
#   'artist_name': 'Ghost',
#   'album_name': 'Meliora (Deluxe Edition)',
#   'genres': 'Metal',
#   'keywords': 'vessel of possibilities, green muse, soul mobility, seals, spirit, absinthe',
#   'emotional': 'journey, challenges, mystery, vision, inevitability',
#   'synopsis': 'The lyrics describe a journey towards the unknown, using the metaphor of absinthe as a gateway to new possibilities and the challenges that come with it, leading to a vision that cannot be inherited by earthly beings.'},
#  {'track_name': 'Shameless',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Beauty Behind The Madness',
#   'genres': 'R&B',
#   'keywords': 'love, touch, pain, scared, be there',
#   'emotional': 'love, scared, pain, hurt, destructive',
#   'synopsis': 'The song expresses the theme of a person who is feared of being loved and seeks validation and physical intimacy from someone, despite their own self-destructive tendencies and fear of being hurt.'},
#  {'track_name': 'In The Night',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Beauty Behind The Madness',
#   'genres': 'R&B',
#   'keywords': 'All alone, World without end or beginning, Co-dependent, Night, Dancing',
#   'emotional': 'Alone, Co-dependent, Pain, Memories, Dancing',
#   'synopsis': 'The lyrics describe a woman who is alone and relies too much on someone, possibly an abusive relationship, and in the night, she dances to relieve the pain and memories of her past.'},
#  {'track_name': 'Real Life',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Beauty Behind The Madness',
#   'genres': 'R&B',
#   'keywords': 'destructive, love, mama, real life, regret',
#   'emotional': 'regret, reality, acceptance, destructiveness, fate',
#   'synopsis': "The lyrics describe a person who has a history of pushing away those who love them, causing Mama to call them destructive. They reflect on their past actions and the regret they don't allow themselves to feel, as they believe they're not worthy of love and not capable of change. They accept their fate and acknowledge the reality of their choices, knowing it's too late for redemption."},
#  {'track_name': 'Acquainted',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Beauty Behind The Madness',
#   'genres': 'R&B',
#   'keywords': "Baby, you're no good, acquainted, touching, dangerous",
#   'emotional': 'attraction, hesitance, emotions, hesitation, danger',
#   'synopsis': "The speaker expresses his attraction towards a woman, despite being warned about her and knowing that she's not good for him. He admits to putting in time and feeling strong emotions towards her, but is hesitant to label their relationship as love due to the potential danger. He also acknowledges his past complacency and the temptation of other women."},
#  {'track_name': 'As You Are',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Beauty Behind The Madness',
#   'genres': 'R&B',
#   'keywords': 'love, relationship, acceptance, heartbreak, commitment',
#   'emotional': 'love, commitment, acceptance, heartbreak, desire',
#   'synopsis': "The lyrics express the speaker's commitment to a flawed and potentially heartbreaking relationship, emphasizing the importance of accepting and loving the other person despite their imperfections."},
#  {'track_name': 'Losers',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Beauty Behind The Madness',
#   'genres': 'R&B',
#   'keywords': 'self-education, relationship, qualification, sense-making, independence',
#   'emotional': 'independence, self-reliance, questioning, relationships, doubt',
#   'synopsis': "The lyrics express the idea of self-reliance and independence, as the singer teaches themselves and makes their own sense without relying on others. The theme of the lyrics also touches on the concept of qualification and relationships, as the singer questions what others can offer them that they don't already know and emphasizes their own qualifications."},
#  {'track_name': "Can't Feel My Face",
#   'artist_name': 'The Weeknd',
#   'album_name': 'Beauty Behind The Madness',
#   'genres': 'R&B',
#   'keywords': 'love, relationship, numbness, death, beauty',
#   'emotional': 'love, addiction, numbness, pain, acceptance',
#   'synopsis': 'The lyrics express the idea of a toxic and addictive love, where the speaker knows that their partner will bring them harm, but they cannot resist the allure and continue to love them, ultimately accepting that they will both be beautiful and stay young, even as they face misery and numbness.'},
#  {'track_name': 'Tell Your Friends',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Beauty Behind The Madness',
#   'genres': 'R&B',
#   'keywords': 'reckless, direction, flexing, attention, patience',
#   'emotional': 'independence, rebellion, confidence, disregard, nonchalance',
#   'synopsis': "The lyrics express a reckless and independent attitude, with a focus on living life on one's own terms and disregarding societal norms and expectations."},
#  {'track_name': 'Prisoner',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Beauty Behind The Madness',
#   'genres': 'R&B',
#   'keywords': 'love, addiction, decisions, emotions, destiny',
#   'emotional': 'longing, emptiness, burning soul, struggle, dependence',
#   'synopsis': "The lyrics express the speaker's dependence on love to improve their life and their struggle with addiction, while acknowledging their own selfish desires and the challenges of making decisions. The speaker reflects on their past experiences and their feelings, which can be described as longing, emptiness, and burning soul."},
#  {'track_name': 'The Hills',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Beauty Behind The Madness',
#   'genres': 'R&B',
#   'keywords': 'half-past five, call, love, touch, fucked up',
#   'emotional': 'love, hiding, desire, intimacy, struggle',
#   'synopsis': "The lyrics describe a person expressing their love for someone, revealing their true self when they're 'fucked up', and the speaker's attempts to keep their relationship a secret."},
#  {'track_name': 'Dark Times',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Beauty Behind The Madness',
#   'genres': 'R&B',
#   'keywords': 'waking up, blood, bruised eye, drunk, lies',
#   'emotional': 'honesty, regret, disappointment, vulnerability, reflection',
#   'synopsis': "The lyrics describe a speaker who wakes up with a bruised eye and blood on their pillow, admitting to drinking too much and lying to someone. They reflect on their past actions, acknowledging that it's not the right time for someone to fall in love with them due to their dishonesty. The speaker also mentions their 'dark times,' during which they return to the streets and make promises they cannot keep."},
#  {'track_name': 'Often',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Beauty Behind The Madness',
#   'genres': 'R&B',
#   'keywords': 'infatuation, sexual encounters, repeated actions, fame and wealth, desire and attraction',
#   'emotional': 'infatuation, desire, attraction, repetition, confidence',
#   'synopsis': "The song describes the speaker's infatuation and repeated sexual encounters, along with their infatuation with fame and wealth, and the desire and attraction that drives their actions."},
#  {'track_name': 'Angel',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Beauty Behind The Madness',
#   'genres': 'R&B',
#   'keywords': 'angel, love, hope, wings, life',
#   'emotional': 'hope, love, desire, longing, emptiness',
#   'synopsis': "The song expresses the speaker's belief in an angel-like figure they have encountered, and their hope for both of them to find love despite their current lives. They see the angel's wings and acknowledge their own lives, with sin and emptiness, but believe that time will reveal if they are meant to be together."},
#  {'track_name': 'Call Out My Name',
#   'artist_name': 'The Weeknd',
#   'album_name': 'My Dear Melancholy,',
#   'genres': 'R&B',
#   'keywords': 'relationship, help, comfort, love, mistake',
#   'emotional': 'love, desire, regret, longing, deception',
#   'synopsis': 'The song describes a relationship where one person helped and gave comfort to the other, but falling in love was a mistake. The singer expresses a desire for the other person to stay with him despite their lack of interest, and admits to lying about not feeling anything. Ultimately, the singer realizes he was just a pit stop for the other person.'},
#  {'track_name': 'I Was Never There',
#   'artist_name': 'The Weeknd',
#   'album_name': 'My Dear Melancholy,',
#   'genres': 'R&B',
#   'keywords': 'What makes a man cry, Matter, Happiness, Sex, Love',
#   'emotional': 'Sadness, Despair, Emptiness, Hopelessness, Healing',
#   'synopsis': "The lyrics express the feelings of a man who is dealing with deep sadness and despair. He questions what is making him feel this way and turns to meaningless sex as a form of healing. The theme of the song seems to be about the emptiness and hopelessness that can come with unrequited love and the effects it can have on a person's emotional well-being."},
#  {'track_name': 'Wasted Times',
#   'artist_name': 'The Weeknd',
#   'album_name': 'My Dear Melancholy,',
#   'genres': 'R&B',
#   'keywords': 'love, ex-partner, jealousy, relationship, sex',
#   'emotional': 'longing, jealousy, desire, regret, confusion',
#   'synopsis': "The song expresses the speaker's difficulty moving on from a past relationship, despite the pain and heartache caused by the ex-partner. The speaker repeatedly questions who the ex-partner is with now and what they have that the speaker doesn't. The lyrics also contain sexual innuendos and a desire for the ex-partner's love and attention."},
#  {'track_name': 'Try Me',
#   'artist_name': 'The Weeknd',
#   'album_name': 'My Dear Melancholy,',
#   'genres': 'R&B',
#   'keywords': 'try me, put your pride aside, best I ever had, remind me, let me know',
#   'emotional': 'longing, desire, communication, reconnection, past connection',
#   'synopsis': 'The lyrics express a longing and desire for communication and reconnection between two people. The singer asks the listener to try them out again and reminds them of their past connection, urging them to let go of their pride and come back to the singer.'},
#  {'track_name': 'Privilege',
#   'artist_name': 'The Weeknd',
#   'album_name': 'My Dear Melancholy,',
#   'genres': 'R&B',
#   'keywords': 'last goodbyes, suffering, pain, blues, red pills',
#   'emotional': 'let go, pain, suffering, blues, move on',
#   'synopsis': "The lyrics express the speaker's intention to let go of a past relationship and move on, using various methods such as denial, distraction, and self-medication."},
#  {'track_name': 'Hurt You',
#   'artist_name': 'The Weeknd',
#   'album_name': 'My Dear Melancholy,',
#   'genres': 'R&B',
#   'keywords': 'relationship, enemy, love, hurt, warning',
#   'emotional': 'pain, despair, hurt, suicide, complex',
#   'synopsis': 'The lyrics express a past relationship that caused pain and feelings of despair, resulting in thoughts of suicide. The speaker warns against getting involved with them, but also offers themselves as a distraction for the pain. The theme revolves around past hurt and the complex emotions that come with it.'},
#  {'track_name': 'Duality',
#   'artist_name': 'Slipknot',
#   'album_name': 'Vol. 3: The Subliminal Verses',
#   'genres': 'Metal',
#   'keywords': 'pain, eyes, ache, fingers, never ends',
#   'emotional': 'pain, despair, resignation, frustration, hopelessness',
#   'synopsis': 'The lyrics express feelings of intense pain and a desire to escape it. The speaker has tried various means to alleviate the pain, but it continues to persist and consume them. They feel trapped and resigned to their fate.'},
#  {'track_name': 'Before I Forget',
#   'artist_name': 'Slipknot',
#   'album_name': 'Vol. 3: The Subliminal Verses',
#   'genres': 'Metal',
#   'keywords': 'Claustrophobia, Home, Bizarre, Remember, End',
#   'emotional': 'Trapped, Bizarre, Catastrophic, Remembering, End',
#   'synopsis': 'The lyrics express feelings of being trapped and catastrophic, with a recurring theme of remembering before forgetting that one is a world before a man.'},
#  {'track_name': "Can't Get You out of My Head",
#   'artist_name': 'Kylie Minogue',
#   'album_name': 'Fever',
#   'genres': 'Rock',
#   'keywords': 'obsession, love, thoughts, night, forever',
#   'emotional': 'obsession, longing, desire, passion, love',
#   'synopsis': "The lyrics express the singer's inability to get the person they are infatuated with out of their head and their longing to be with them forever."},
#  {'track_name': 'Come into My World',
#   'artist_name': 'Kylie Minogue',
#   'album_name': 'Fever',
#   'genres': 'Rock',
#   'keywords': 'love, relationship, heart, emotion, desire',
#   'emotional': 'longing, desire, emotional_connection, hope, love',
#   'synopsis': "The lyrics express the speaker's longing for love and companionship, using imagery of arms, hearts, and eyes to convey their emotional connection and need for someone to be a part of their world."},
#  {'track_name': 'In Your Eyes',
#   'artist_name': 'Kylie Minogue',
#   'album_name': 'Fever',
#   'genres': 'Rock',
#   'keywords': 'love, relationship, desire, introspection, emotion',
#   'emotional': 'love, desire, infatuation, introspection, sinking feeling',
#   'synopsis': "The lyrics express the speaker's feelings of being captivated by someone, unable to leave their presence. They describe a deep connection and a strong desire to be with this person."},
#  {'track_name': 'Grenade',
#   'artist_name': 'Bruno Mars',
#   'album_name': 'Doo-Wops & Hooligans',
#   'genres': 'Pop',
#   'keywords': 'love, relationship, sacrifice, regret, commitment',
#   'emotional': 'love, sacrifice, regret, frustration, disappointment',
#   'synopsis': "The song expresses the speaker's deep love and willingness to sacrifice everything for their partner, despite the partner's inconsistency and lack of commitment."},
#  {'track_name': 'Toxic',
#   'artist_name': 'BoyWithUke',
#   'album_name': 'Toxic',
#   'genres': 'Alternative',
#   'keywords': 'drowning, new friends, empty, toxic friends, alone',
#   'emotional': 'loneliness, isolation, longing, let down, despair',
#   'synopsis': 'The lyrics express feelings of loneliness and isolation as the speaker feels let down by their friends and longs for companionship. They describe their friends as toxic and ambitionless, and express a desire to be alone, yet still feel empty without someone else.'},
#  {'track_name': 'G.O.A.T.',
#   'artist_name': 'Polyphia',
#   'album_name': 'New Levels New Devils',
#   'genres': 'Rock',
#   'keywords': '',
#   'emotional': '',
#   'synopsis': ''},
#  {'track_name': 'So Strange (feat. Cuco)',
#   'artist_name': 'Polyphia',
#   'album_name': 'New Levels New Devils',
#   'genres': 'Rock',
#   'keywords': 'need, think, every night, hand, mind',
#   'emotional': 'longing, need, desire, thoughts, infatuation',
#   'synopsis': "The lyrics express the speaker's deep longing for someone and their inability to forget them, as they repeat the phrase 'I think of you like every night'."},
#  {'track_name': 'Rich Kids (feat. Yvette Young)',
#   'artist_name': 'Polyphia',
#   'album_name': 'New Levels New Devils',
#   'genres': 'Rock',
#   'keywords': '',
#   'emotional': '',
#   'synopsis': ''},
#  {'track_name': 'Yas (feat. Mario Camarena and Erick Hansel)',
#   'artist_name': 'Polyphia',
#   'album_name': 'New Levels New Devils',
#   'genres': 'Rock',
#   'keywords': 'send, bottle, full auto, repetition, instructions',
#   'emotional': 'instruction, repetition, automatic, action, command',
#   'synopsis': "The lyrics repeat the instruction to 'Send the bottle, full auto'."},
#  {'track_name': 'Maria',
#   'artist_name': 'Hwa Sa',
#   'album_name': 'María',
#   'genres': 'Electro, Asian Music',
#   'keywords': 'María, love, solitude, heartache, night',
#   'emotional': 'heartache, solitude, pleading, beauty, night',
#   'synopsis': 'The lyrics express feelings of heartache and solitude, with the recurring theme of pleading with María not to abandon or ignore the speaker, and emphasizing the beauty of the night.'},
#  {'track_name': 'To Rid the Disease',
#   'artist_name': 'Opeth',
#   'album_name': 'Damnation',
#   'genres': 'Metal, Rock, Hard Rock',
#   'keywords': 'absence, innocence, trust, creation, failure',
#   'emotional': 'loss, distrust, frustration, despair, creation',
#   'synopsis': 'The lyrics express feelings of loss of trust and innocence, as well as the struggle with failure and its impact on the creator.'},
#  {'track_name': 'Closure',
#   'artist_name': 'Opeth',
#   'album_name': 'Damnation',
#   'genres': 'Metal, Rock, Hard Rock',
#   'keywords': 'self-healing, redemption, reflection, emotional transformation, hope',
#   'emotional': 'introspection, healing, redemption, hope, longing',
#   'synopsis': 'The lyrics express the theme of introspection, healing, and finding redemption through self-reflection. The speaker looks inward and tries to heal themselves, disposing of old skin and past sins. They await news of the future with hope, but have forgotten past promises. Despite the current sunshine, they long for darkness.'},
#  {'track_name': 'Death Whispered a Lullaby',
#   'artist_name': 'Opeth',
#   'album_name': 'Damnation',
#   'genres': 'Metal, Rock, Hard Rock',
#   'keywords': 'road, fireflies, lost souls, peace of mind, men returning',
#   'emotional': 'searching, peace, fear, encouragement, forgetfulness',
#   'synopsis': 'The lyrics depict a journey through the woods, where people are seeking peace of mind among lost souls. The speaker encourages someone to sleep amidst moving shadows and closing eyelids, promising that the world and memories will fade away.'},
#  {'track_name': 'In My Time of Need',
#   'artist_name': 'Opeth',
#   'album_name': 'Damnation',
#   'genres': 'Metal, Rock, Hard Rock',
#   'keywords': 'life, goodbye, change, pain, rain',
#   'emotional': 'despair, loss, contemplation, sadness, questioning',
#   'synopsis': 'The lyrics express feelings of despair, loss, and contemplation of moving on from a past relationship, using the metaphor of summer being far away and rain symbolizing sadness. The speaker is at the point of considering ending it all and is drifting through the stages of grief, while questioning if anyone would be there to help in their time of need.'},
#  {'track_name': "Creepin'",
#   'artist_name': 'Metro Boomin',
#   'album_name': 'HEROES & VILLAINS',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'deception, heartbreak, infidelity, relationship, emotional turmoil',
#   'emotional': 'heartache, pain, infidelity, betrayal, loneliness',
#   'synopsis': "The lyrics express the pain and emotional distress of a person discovering their partner's infidelity. The singer pleas with their partner to keep it a secret and not let it show, as they can't handle the heartache any longer. The partner is described as having moved on to a new life, leaving the singer feeling alone and lost."},
#  {'track_name': 'Too Many Nights',
#   'artist_name': 'Metro Boomin',
#   'album_name': 'HEROES & VILLAINS',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'Metro, Honorable C.N.O.T.E, lyrics, music, rap',
#   'emotional': 'confident, luxury, pleasure, wealth, celebration',
#   'synopsis': "The song's lyrics describe themes of material wealth, pleasure-seeking, and confidence. The artist talks about spending money on women, partying, and living a lavish lifestyle."},
#  {'track_name': 'Superhero (Heroes & Villains)',
#   'artist_name': 'Metro Boomin',
#   'album_name': 'HEROES & VILLAINS',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'superhero, dope, money, wealth, success',
#   'emotional': 'power, confidence, aggression, dominance, victory',
#   'synopsis': "The lyrics describe a person's transformation into a superhero and a wealthy individual through the use of drugs and money. The person is living a lavish lifestyle, dominating the streets, and accumulating wealth."},
#  {'track_name': 'Do I Wanna Know?',
#   'artist_name': 'Arctic Monkeys',
#   'album_name': 'AM',
#   'genres': 'Alternative',
#   'keywords': 'relationship, feelings, thoughts, calling, kiss',
#   'emotional': 'longing, desire, reminiscing, hoping, yearning',
#   'synopsis': "The lyrics express the singer's longing for a past or current relationship, and their desire to reconnect. They ask the listener if their feelings are mutual and reminisce on the nights they spent together, saying things they couldn't say the next day."},
#  {'track_name': 'When Worlds Collide',
#   'artist_name': 'Powerman 5000',
#   'album_name': 'Tonight The Stars Revolt',
#   'genres': 'Rock',
#   'keywords': 'collide, worlds, control, suffer, take over',
#   'emotional': 'suffer, take over, collide, ready, go',
#   'synopsis': 'The lyrics express the theme of worlds colliding and the inevitable outcome of taking over and suffering. The speaker is ready to go with someone and questions their motivations and identity, ultimately taking over and leading them.'},
#  {'track_name': 'The Ketchup Song (Aserejé)',
#   'artist_name': 'Las Ketchup',
#   'album_name': 'Aserejé (The Ketchup Song)',
#   'genres': 'Pop',
#   'keywords': 'Diego, DJ, Ritmo ragatanga, Canción deseada, Alegria',
#   'emotional': 'Alegria, Possesion, Enjoyment, Dancing, Rhythm',
#   'synopsis': "A man named Diego, with a blue marine suit and the moon in his eyes, is dancing to the rhythm of a DJ's music. He is possessed by the music and enjoys the song most desired by him, repeating the phrase 'Aserejé ja de je' numerous times."},
#  {'track_name': 'Not You Too',
#   'artist_name': 'Drake',
#   'album_name': 'Dark Lane Demo Tapes',
#   'genres': 'Rap/Hip Hop',
#   'keywords': "First time, Hurtin' deeply, Trust, Relationship, Deception",
#   'emotional': 'Pain, Longing, Trust issues, Deception, Confusion',
#   'synopsis': "The song is about expressing pain and longing for trust in a relationship, while acknowledging past deception and questioning the authenticity of the other person's feelings."},
#  {'track_name': 'July',
#   'artist_name': 'Betcha',
#   'album_name': 'July',
#   'genres': 'Alternative',
#   'keywords': 'rain, gray day, life is a poem, catacombs, July',
#   'emotional': 'regret, longing, reflection, simplicity, creativity',
#   'synopsis': "The lyrics express a sense of regret for past actions and a longing for simple pleasures. The metaphor of 'life is a poem' is used to convey the idea that we create our own experiences through our choices."},
#  {'track_name': 'Psychosocial',
#   'artist_name': 'Slipknot',
#   'album_name': 'All Hope Is Gone',
#   'genres': 'Metal',
#   'keywords': 'desert, graves, hate, preservation, martyr',
#   'emotional': 'done, hopelessness, despair, emptiness, surrender',
#   'synopsis': "The lyrics express feelings of being done and wanting to move on from a painful past. The speaker feels trapped and empty, with a sense of despair and a longing for release. The use of the phrase 'the rain will kill us all' suggests a sense of hopelessness and surrender."},
#  {'track_name': 'Sulfur',
#   'artist_name': 'Slipknot',
#   'album_name': 'All Hope Is Gone',
#   'genres': 'Metal',
#   'keywords': 'guilt, shame, decisions, suffering, surviving',
#   'emotional': 'guilt, shame, suffering, inner turmoil, acceptance',
#   'synopsis': "The lyrics express feelings of guilt, shame, and the burden of making one's own decisions, despite the suffering and potential for failure. The speaker acknowledges their inner turmoil and the importance of facing it, even if it feels like sulfur."},
#  {'track_name': 'Selfish',
#   'artist_name': 'Little Simz',
#   'album_name': 'GREY Area',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'selfishness, ego, friendship, denial, materialism',
#   'emotional': 'selfishness, denial, conflict, ego, reflection',
#   'synopsis': 'The lyrics express the theme of self-centeredness and denial, with references to past experiences and material possessions serving as sources of comfort and validation.'},
#  {'track_name': 'Wounds',
#   'artist_name': 'Little Simz',
#   'album_name': 'GREY Area',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'gun, violence, life choices, destiny, love',
#   'emotional': 'lost, love, pain, fear, longing',
#   'synopsis': 'The lyrics describe the destructive nature of living a violent lifestyle, the idolization of rappers and gun culture, the emotional turmoil of losing loved ones or being trapped in a cycle of violence, and the longing for love and understanding as a means to escape.'},
#  {'track_name': 'Therapy',
#   'artist_name': 'Little Simz',
#   'album_name': 'GREY Area',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'alone, overload, therapy, fear, clarity',
#   'emotional': 'isolation, overload, fear, seeking_clarity, introspection',
#   'synopsis': 'The lyrics express feelings of isolation, overload, and fear, with a recurring theme of therapy and seeking clarity. The speaker reflects on past experiences, relationships, and the desire for freedom and introspection.'},
#  {'track_name': 'Boss',
#   'artist_name': 'Little Simz',
#   'album_name': 'GREY Area',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'boss, dream, stress, lyrics, discover',
#   'emotional': 'ambition, determination, frustration, success, reflection',
#   'synopsis': "The lyrics describe a person's journey from following their dreams and overcoming obstacles to becoming a successful 'boss'. The theme revolves around the idea of staying focused, rejecting negativity, and discovering one's potential."},
#  {'track_name': 'Venom',
#   'artist_name': 'Little Simz',
#   'album_name': 'GREY Area',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'suicide, mind, high, soul, venom',
#   'emotional': 'mental_distress, defiance, desire_escape, frustration, aggression',
#   'synopsis': 'The lyrics express feelings of mental distress, a desire to escape reality through substances, and a defiant attitude towards those who doubt or challenge the speaker.'},
#  {'track_name': 'Pressure',
#   'artist_name': 'Little Simz',
#   'album_name': 'GREY Area',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'pressure, life, struggle, power, freedom',
#   'emotional': 'pressure, struggle, desire, criticism, freedom',
#   'synopsis': "The lyrics express feelings of pressure to succeed and the struggle against oppression, as well as the desire for freedom and the criticism of those in power. The artist questions the actions and motives of those in authority and the impact they have on people's lives, particularly young Black people."},
#  {'track_name': 'Indestructible',
#   'artist_name': 'Disturbed',
#   'album_name': 'Indestructible',
#   'genres': 'Metal',
#   'keywords': 'mission, powers, carry the colors, oath, defend',
#   'emotional': 'determination, indestructible, fight, war, protect',
#   'synopsis': 'The lyrics describe a person being called away for a mission, sworn to defend and carry colors, becoming indestructible and a master of war.'},
#  {'track_name': 'Bat Country',
#   'artist_name': 'Avenged Sevenfold',
#   'album_name': 'City of Evil',
#   'genres': 'Rock, Hard Rock',
#   'keywords': 'He who makes a beast, Fiery blaze, New sights, Mental fiction, Vision unclear',
#   'emotional': 'Isolation, Destruction, Freedom, Longing, Desperation',
#   'synopsis': "The lyrics express a sense of isolation and self-destruction as the speaker deals with the pain of being a man. They long for freedom and new experiences, even if it means becoming a 'beast' or losing their sanity."},
#  {'track_name': 'Natural',
#   'artist_name': 'Imagine Dragons',
#   'album_name': 'Origins (Deluxe)',
#   'genres': 'Alternative',
#   'keywords': 'house, consequence, cost, stars, Heaven',
#   'emotional': 'strength, adversity, cost, instinct, world',
#   'synopsis': 'The lyrics express a theme of standing strong in the face of adversity and the cost of making it in the world, using metaphors of houses, stars, and natural instincts.'},
#  {'track_name': 'Pretty',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Kiss Land (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'love, heartbreak, reunion, absence, longing',
#   'emotional': 'love, heartbreak, longing, reunion, desire',
#   'synopsis': 'The lyrics describe a person returning to a former lover after a year of separation. They express the feeling of heartbreak and the longing for reunion, as well as the belief that the former lover will feel more beautiful and loved in their presence.'},
#  {'track_name': 'Odd Look',
#   'artist_name': 'Kavinsky',
#   'album_name': 'Kiss Land (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'rain, snake, lead, elevating, you were mine',
#   'emotional': 'amazing, enslaved, rain, elevating, you were mine',
#   'synopsis': 'The speaker is with someone who is compared to a snake, and they are trying to find a way to be with them despite the rain and the feeling of being enslaved. The person is described as being elevating and making things amazing.'},
#  {'track_name': 'Tears In The Rain',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Kiss Land (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'Adjust to the fame, No one will love you like her, Pointless, Tears in the rain, Die with a smile',
#   'emotional': 'Loneliness, Sadness, Acceptance, Love, Embrace',
#   'synopsis': 'The lyrics express feelings of loneliness, sadness, and acceptance after a lost love. The idea that no one can replace the love of the one who has left is repeated throughout, and the acceptance of that reality leads to the embracing of what comes next and dying with a smile.'},
#  {'track_name': 'Adaptation',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Kiss Land (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'love, heart, sun, day, realization',
#   'emotional': 'regret, loss, realization, adaptation, love',
#   'synopsis': 'The song expresses a regret for letting go of a potential love, the speaker acknowledges their own faults and the loss of that love, and adapts to a new life.'},
#  {'track_name': 'Belong To The World',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Kiss Land (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'wind, clouds, promise, love, belong',
#   'emotional': 'longing, detachment, clinginess, love, indifference',
#   'synopsis': "The lyrics express a speaker's longing for a relationship and their partner's seeming indifference. The speaker acknowledges their own lifelessness and the partner's apparent detachment, but still clings to their love and the moments they've shared."},
#  {'track_name': 'Professional',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Kiss Land (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'somebody, happiness, professional, love, sophisticated',
#   'emotional': 'happiness, emptiness, pressure, disposable, fulfillment',
#   'synopsis': "The lyrics describe the experience of someone who has achieved success but feels empty and unfulfilled, using the metaphor of being a 'somebody' in a 'nobody town'. They discuss the idea of love being professional and sophisticated, but also numbing and disposable. The theme seems to be about the search for meaning and fulfillment in life, despite past hardships and the pressures of society."},
#  {'track_name': 'Kiss Land',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Kiss Land (Deluxe)',
#   'genres': 'R&B',
#   'keywords': "stage, ballin', love, strip, show",
#   'emotional': 'confident, intimacy, love, freedom, performance',
#   'synopsis': 'The lyrics describe a confident and wealthy individual who performs on stage and enjoys the company of a woman. He enjoys her physical presence and the intimacy of their relationship, which he compares to a show. He also mentions his past experiences and newfound freedom, as well as his love for the woman which nothing can change.'},
#  {'track_name': 'Wanderlust',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Kiss Land (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'love, diamond, wanderlust, apprehensiveness, inhibition',
#   'emotional': 'love, passion, fear, inhibition, embracement',
#   'synopsis': 'The lyrics express the theme of living in the moment and embracing love and passion, despite fear and inhibitions, comparing it to a wildfire and something bigger and stronger than typical love and trust.'},
#  {'track_name': 'The Town',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Kiss Land (Deluxe)',
#   'genres': 'R&B',
#   'keywords': 'relationship, diamond rings, provide, deserve, road',
#   'emotional': 'regret, love, support, infidelity, deserving',
#   'synopsis': 'The lyrics describe a past relationship where the speaker acknowledges the good times they had and the desire to provide for their former partner, who now deserves to be honored with a crown or throne. The speaker also expresses regret for not being able to stay and their past infidelity, but offers to be a source of love and support again.'},
#  {'track_name': 'Wainek Min Zaman',
#   'artist_name': 'Yazan Haifawi',
#   'album_name': 'Wahad',
#   'genres': 'Alternative',
#   'keywords': 'love, time, searching, encounter, regret',
#   'emotional': 'longing, regret, nostalgia, desire, yearning',
#   'synopsis': "The lyrics express the speaker's longing for a lost love and their regret for not having found them in the past. They reminisce about the times they spent together and wish for their return."},
#  {'track_name': 'Under Pressure',
#   'artist_name': 'Queen',
#   'album_name': 'Hot Space (Deluxe Edition 2011 Remaster)',
#   'genres': 'Rock',
#   'keywords': 'Pressure, People on streets, Terror, Love, Dare',
#   'emotional': 'Pressure, Terror, Desire, Love, Hope',
#   'synopsis': 'The song lyrics describe the feeling of being under pressure and the terror of the world around us. The theme revolves around the idea of love being a way to cope with the pressure and the desire to change our way of caring about ourselves and others.'},
#  {'track_name': '7 Words',
#   'artist_name': 'Deftones',
#   'album_name': 'Adrenaline',
#   'genres': 'Rock, Hard Rock',
#   'keywords': 'self-esteem, dreams, mind, glorification, emotional turmoil',
#   'emotional': 'frustration, anger, low self-esteem, emotional pain, desire to escape',
#   'synopsis': "The lyrics express feelings of low self-esteem, frustration, and anger towards someone who has hurt the speaker's dreams and sense of identity. The speaker feels their mind has been taken over by these negative thoughts, and they express a desire to escape from the emotional pain."},
#  {'track_name': 'Birthmark',
#   'artist_name': 'Deftones',
#   'album_name': 'Adrenaline',
#   'genres': 'Rock, Hard Rock',
#   'keywords': 'fly, lie, right, cherished, birth',
#   'emotional': 'desire, deception, longing, cherished, flight',
#   'synopsis': 'The lyrics express a desire to be with someone, to make them fly with lies, and to be cherished by them, despite the deceit.'},
#  {'track_name': 'Lifter',
#   'artist_name': 'Deftones',
#   'album_name': 'Adrenaline',
#   'genres': 'Rock, Hard Rock',
#   'keywords': 'desire, longing, intimacy, emotional_pain, monstrous_behavior',
#   'emotional': 'longing, desire, emotional_pain, intimacy, frustration',
#   'synopsis': "The lyrics express a deep longing to be like someone else, with themes of emotional pain, intimacy, and monstrous behavior. The speaker uses the metaphor of being 'monsters' to describe their actions and desires."},
#  {'track_name': 'Engine No. 9',
#   'artist_name': 'Deftones',
#   'album_name': 'Adrenaline',
#   'genres': 'Rock, Hard Rock',
#   'keywords': 'guns, rolling, street life, underground, rapping',
#   'emotional': 'power, aggression, violence, control, defiance',
#   'synopsis': "The lyrics describe a person in a violent, street environment, boasting about their power and control over others, and living a dangerous lifestyle. They also reference a 'peer side whore' and a 'mother she' who refuses to drain herself and become someone else."},
#  {'track_name': 'Bored',
#   'artist_name': 'Deftones',
#   'album_name': 'Adrenaline',
#   'genres': 'Rock, Hard Rock',
#   'keywords': 'Hear, Wither, Bury, Reborn, I get bored',
#   'emotional': 'Anger, Desire, Transformation, Boredom, Confusion',
#   'synopsis': 'The lyrics express a theme of feeling trapped and bored, desiring change and a more meaningful connection, while also expressing emotions of anger and a desire for transformation.'},
#  {'track_name': 'Root',
#   'artist_name': 'Deftones',
#   'album_name': 'Adrenaline',
#   'genres': 'Rock, Hard Rock',
#   'keywords': 'love, judgment, barred, cry, psycho',
#   'emotional': 'love, cry, judgment, hidden, psycho',
#   'synopsis': 'The lyrics express feelings of being judged, love, and a desire to be loved, as well as a sense of being hidden or hidden from others, and a feeling of being a psycho or misunderstood.'},
#  {'track_name': 'One Weak',
#   'artist_name': 'Deftones',
#   'album_name': 'Adrenaline',
#   'genres': 'Rock, Hard Rock',
#   'keywords': 'Meeting Christ alone, Misunderstood, Burning, Breach, Scars',
# ...
#   'synopsis': 'The lyrics express the idea of reflecting on past days spent together and apart in a relationship, emphasizing the importance of heartfelt connections.'},
#  {'track_name': 'Hail to the King',
#   'artist_name': 'Avenged Sevenfold',
#   'album_name': 'Hail to the King',
#   'genres': 'Rock',
#   'keywords': 'war, death, kingship, chaos, fear',
#   'emotional': 'fear, chaos, despair, defiance, submission',
#   'synopsis': 'The lyrics describe a town under the threat of war and death, with references to children as orphans and bodies hanging in the streets. A king is mentioned, who spills blood and claims the throne, bringing both chaos and order. The people are urged to kneel and stand in the sun, suggesting both submission and defiance.'},
#  {'track_name': 'You First',
#   'artist_name': 'Paramore',
#   'album_name': 'This Is Why',
#   'genres': 'Alternative',
#   'keywords': 'revenge, privilege, animal, karma, horror',
#   'emotional': 'trapped, uncertainty, revenge, hope, fear',
#   'synopsis': "The lyrics express the speaker's feeling of being trapped by their own actions and the actions of others, with a theme of revenge and the uncertainty of karma."},
#  {'track_name': 'Crime Pays',
#   'artist_name': 'Freddie Gibbs',
#   'album_name': 'Bandana',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'Crime pays, Nigga, Drug use, Life and death, Gang culture',
#   'emotional': 'Desperation, Survival, Anger, Powerlessness, Violence',
#   'synopsis': 'The lyrics describe the life of individuals involved in crime and gang culture, with references to drug use and the consequences of living by the game. The theme revolves around the idea that crime pays but comes with risks and the constant cycle of living and dying in this lifestyle.'},
#  {'track_name': 'I Really Want to Stay at Your House',
#   'artist_name': 'Rosa Walton',
#   'album_name': 'Cyberpunk 2077: Radio, Vol. 2 (Original Soundtrack)',
#   'genres': 'Films/Games, Film Scores',
#   'keywords': 'relationship, breakup, longing, self-reflection, decision',
#   'emotional': 'longing, regret, confusion, grief, desire',
#   'synopsis': "The lyrics express the speaker's feelings of longing and regret after a breakup. They lament the absence of their former partner and question their own actions and emotions. The speaker contemplates the idea of moving on and making new experiences, but also grapples with feelings of being broken apart and wanting to ignore their ex."},
#  {'track_name': 'telepatía',
#   'artist_name': 'Kali Uchis',
#   'album_name': 'Sin Miedo (del Amor y Otros Demonios) ∞',
#   'genres': 'Latin Music',
#   'keywords': 'telepathy, love, mind reading, night, melody',
#   'emotional': 'longing, desire, connection, intimacy, understanding',
#   'synopsis': "The lyrics describe a longing for love and connection, expressing the desire to read a person's mind and be close to them, even if physically apart. The speaker asserts their ability to see through the other person and understand their thoughts."},
#  {'track_name': '¡aquí yo mando!',
#   'artist_name': 'Kali Uchis',
#   'album_name': 'Sin Miedo (del Amor y Otros Demonios) ∞',
#   'genres': 'Latin Music',
#   'keywords': 'mamacita, decisions, boss, obsession, fuego',
#   'emotional': 'confident, dominant, power, control, boastful',
#   'synopsis': 'The lyrics describe a confident and dominant individual who takes control and makes all the decisions in a relationship. They boast about their power and ability to choose partners and make them obedient. The theme revolves around self-assuredness and dominance.'},
#  {'track_name': 'Bnadilak Ya Habibi',
#   'artist_name': 'Fairuz',
#   'album_name': 'Chante Zaki Nassif',
#   'genres': 'Pop',
#   'keywords': '',
#   'emotional': '',
#   'synopsis': ''},
#  {'track_name': 'Enemy',
#   'artist_name': 'Imagine Dragons',
#   'album_name': 'Enemy (from the series Arcane League of Legends)',
#   'genres': 'Alternative',
#   'keywords': 'searching, enemies, revenge, emotions, adversity',
#   'emotional': 'betrayal, revenge, adversity, determination, emotions',
#   'synopsis': "The lyrics express the feeling of being betrayed and the desire for revenge against one's enemies. The speaker describes how they seek to understand the stories behind the betrayal and how they are ready to fight back. The theme of adversity and the importance of looking out for oneself are recurring."},
#  {'track_name': 'Eb2a 2ablny',
#   'artist_name': 'Fadel Chaker',
#   'album_name': 'Eb2a 2ablny',
#   'genres': '',
#   'keywords': 'God, Sorrow, Love, Struggle, Time',
#   'emotional': 'Longing, Hope, Love, Sorrow, Struggle',
#   'synopsis': "The song expresses a deep longing for God's acceptance and love, despite the speaker's flaws and past mistakes. The lyrics describe feelings of sorrow and struggle, but also the hope of finding peace and living in paradise with the beloved."},
#  {'track_name': 'Nails',
#   'artist_name': 'Saint Levant',
#   'album_name': 'Nails',
#   'genres': 'Pop, Dance',
#   'keywords': 'Visa stress, Followed by Mia Khalifa, People seeking advice, Friendzone, Hating on appearance',
#   'emotional': 'stress, disapproval, surprise, reflection, bullying',
#   'synopsis': "The artist expresses the stress of dealing with a Visa and his girlfriend's disapproval of his popularity. He is surprised by people seeking his advice and those he knew in the past asking for jobs. He reflects on past bullying over his appearance and his current success, and acknowledges the presence of haters."},
#  {'track_name': 'Adult Diversion',
#   'artist_name': 'Alvvays',
#   'album_name': 'Alvvays',
#   'genres': 'Alternative',
#   'keywords': 'admiration, longing, isolation, retreat, obsession',
#   'emotional': 'longing, fear, isolation, admiration, obsession',
#   'synopsis': "The song expresses the speaker's longing and admiration for someone, who appears to be unapproachable. The speaker attempts to get close to them despite their isolation and keeps a padlock on their door. The speaker expresses a fear of rejection and hints at a past failure. The lyrics repeat the phrase 'if I should fall' indicating a fear of losing the object of their affection. The speaker also mentions the idea of wasting moments and going back to university, which may suggest a coming-of-age theme."},
#  {'track_name': 'Dead Man Walking',
#   'artist_name': 'Brent Faiyaz',
#   'album_name': 'Dead Man Walking',
#   'genres': 'R&B',
#   'keywords': '',
#   'emotional': '',
#   'synopsis': ''},
#  {'track_name': 'Strangers In The Night',
#   'artist_name': 'Frank Sinatra',
#   'album_name': 'Nothing But The Best (2008 Remastered)',
#   'genres': 'Jazz',
#   'keywords': 'strangers, night, love, glance, dance',
#   'emotional': 'love, attractions, loneliness, surprise, romance',
#   'synopsis': 'Two strangers meet in the night and through a mutual attraction, end up falling in love.'},
#  {'track_name': 'Alors on danse',
#   'artist_name': 'Stromae',
#   'album_name': 'Cheese',
#   'genres': 'Pop, Dance',
#   'keywords': 'problems, dance, sing, work, love',
#   'emotional': 'problems, distress, escapism, crying, pray',
#   'synopsis': "The lyrics express the cycle of dealing with problems and seeking escape through dancing and singing. The speaker contemplates the source of their troubles and questions whether it's the world or the music that's causing their distress."},
#  {'track_name': 'Counting Stars',
#   'artist_name': 'OneRepublic',
#   'album_name': 'Native',
#   'genres': 'Pop',
#   'keywords': 'losing sleep, dreaming, praying, counting stars, lessons learned',
#   'emotional': 'losing sleep, dreaming, praying, countin stars, feeling alive',
#   'synopsis': "The lyrics express the speaker's longing for change and living life to the fullest, with a focus on finding happiness beyond material wealth and learning from past experiences."},
#  {'track_name': 'Heroes',
#   'artist_name': 'David Bowie',
#   'album_name': '"Heroes" (2017 Remaster)',
#   'genres': 'Pop',
#   'keywords': 'lovers, heroes, one day, beating adversity, king and queen',
#   'emotional': 'happiness, desire, defiance, longing, power',
#   'synopsis': 'The lyrics describe a longing for a day where the speakers can be in a position of power and happiness, despite adversity and challenges, and be together as lovers.'},
#  {'track_name': '20 Wave Caps (feat. Domo Genesis)',
#   'artist_name': 'Earl Sweatshirt',
#   'album_name': 'Doris',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'Doms, rhyming, niggas, flows, progression',
#   'emotional': 'confident, dominant, boasting, proud, successful',
#   'synopsis': "The lyrics express the confidence and dominance of an individual, using metaphors such as 'giant' and 'tyrant', and the repeated use of the name 'Doms'. The speaker is proud of their skills and success, and boasts about their abilities and possessions."},
#  {'track_name': "Don't Stop The Music",
#   'artist_name': 'Rihanna',
#   'album_name': 'Good Girl Gone Bad: Reloaded',
#   'genres': 'Pop',
#   'keywords': 'dance floor, music, party, romance, escaping',
#   'emotional': 'passion, romance, exciting, intimacy, happiness',
#   'synopsis': 'The lyrics describe an individual making their way to a favorite place to dance and party. They meet someone who captures their attention and the two end up dancing together, lost in the music. The theme revolves around escaping and losing oneself in the music and the moment.'},
#  {'track_name': 'Infinity',
#   'artist_name': 'Jaymes Young',
#   'album_name': 'Feel Something',
#   'genres': 'Alternative',
#   'keywords': 'love, infinity, soul, paradise, emotion',
#   'emotional': 'love, intensity, passion, belief, devotion',
#   'synopsis': "The lyrics express the depth and intensity of the speaker's love for someone, describing it as something that will last forever and that they have lost control over. The speaker sees themselves as a 'mad man' for the touch of their loved one, and believes they have been chosen and are gods together."},
#  {'track_name': 'might bang, might not',
#   'artist_name': 'Little Simz',
#   'album_name': 'Drop 6',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'now, love, space, bass, party',
#   'emotional': 'confident, resilient, determined, energetic, celebratory',
#   'synopsis': 'The song expresses confidence, resilience, and a sense of being in the moment, with references to past struggles and successes.'},
#  {'track_name': 'The Eagle Flies Alone',
#   'artist_name': 'Arch Enemy',
#   'album_name': 'Will To Power',
#   'genres': 'Metal, Rock, Hard Rock',
#   'keywords': 'fight, personal freedom, rebellion, self-determination, independence',
#   'emotional': 'rebellion, determination, independence, defiance, resilience',
#   'synopsis': 'The lyrics express the theme of individualism and the desire for personal freedom, as the author goes against societal norms and battles against those who wish to enslave or control them. The author rejects conformity and chooses their own path, even in the face of defeat and betrayal.'},
#  {'track_name': 'Teenagers',
#   'artist_name': 'My Chemical Romance',
#   'album_name': 'The Black Parade',
#   'genres': 'Alternative',
#   'keywords': 'teenagers, scare, living shit out of me, bleed, violent pose',
#   'emotional': 'fear, rebellion, control, violence, harsh environment',
#   'synopsis': 'The song expresses feelings of fear and violence towards teenagers, suggesting a harsh and controlling environment where individuals are monitored and forced to conform, leading to rebellion.'},
#  {'track_name': 'STAY',
#   'artist_name': 'The Kid LAROI',
#   'album_name': 'STAY',
#   'genres': 'Pop',
#   'keywords': 'regret, change, love, stay, need',
#   'emotional': 'regret, longing, fear, attachment, desire',
#   'synopsis': "The lyrics express the speaker's regret for past actions and their inability to change, but also their strong need and desire for their partner to stay with them due to their belief that they can't find someone else as good as them."},
#  {'track_name': "I Was Made For Lovin' You",
#   'artist_name': 'Kiss',
#   'album_name': 'Dynasty',
#   'genres': 'Rock',
#   'keywords': 'love, relationship, desire, intimacy, passion',
#   'emotional': 'desire, passion, love, intimacy, belief',
#   'synopsis': "The lyrics express the speaker's deep desire and belief that they were made for a particular person and vice versa, with a theme of love and wanting to give and receive it fully."},
#  {'track_name': 'Selenium Forest',
#   'artist_name': 'Plini',
#   'album_name': 'Other Things',
#   'genres': 'Metal',
#   'keywords': '',
#   'emotional': '',
#   'synopsis': ''},
#  {'track_name': 'Raining Blood',
#   'artist_name': 'Slayer',
#   'album_name': 'Reign In Blood (Expanded)',
#   'genres': 'Rock',
#   'keywords': 'reprisal, death, red sky, raining, purgatory',
#   'emotional': 'revenge, awaiting, trapped, redemption, emotionally charged',
#   'synopsis': 'The lyrics describe a sense of being trapped and awaiting a reprisal or revenge, with the sky turning red and raining blood. The speaker is awaiting the hour of reprisal, and references a treacherous past and betrayers now above as ornaments. There is a theme of reigning in blood and abolishing rules.'},
#  {'track_name': 'Ana Habibi',
#   'artist_name': 'Mohammed Abdo',
#   'album_name': 'Ana Habibi',
#   'genres': '',
#   'keywords': '',
#   'emotional': '',
#   'synopsis': ''},
#  {'track_name': 'For the First Time',
#   'artist_name': 'Mac DeMarco',
#   'album_name': 'This Old Dog',
#   'genres': 'Alternative',
#   'keywords': 'absence, longing, reunions, emotional struggle, anticipation',
#   'emotional': 'longing, anticipation, difficulty, emotional struggle, absence',
#   'synopsis': 'The lyrics describe the emotional struggle of being apart from someone and the anticipation of their return. The speaker expresses how being without them has been tough and difficult, but they are trying to understand their feelings upon their return.'},
#  {'track_name': 'Heartbeat, Heartbreak',
#   'artist_name': '平田志穂子',
#   'album_name': 'ペルソナ4 オリジナル・サウンドトラック',
#   'genres': 'Films/Games, Film Scores',
#   'keywords': 'heartbeat, heartbreak, dream, promise, aching',
#   'emotional': 'pain, need, heartbreak, longing, frustration',
#   'synopsis': "The lyrics express the speaker's pain and need for love after a broken promise, with recurring themes of heartbeats and heartbreak."},
#  {'track_name': 'BETTER DAYS',
#   'artist_name': 'Rilès',
#   'album_name': 'BETTER DAYS',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'swear, choose, live, thoughts, alone',
#   'emotional': 'determination, struggle, despair, solitude, hope',
#   'synopsis': "The song expresses the speaker's determination to move forward despite the struggles, to quiet their thoughts and live on better days, refusing to give in to their sins or fears."},
#  {'track_name': 'Space Song',
#   'artist_name': 'Beach House',
#   'album_name': 'Depression Cherry',
#   'genres': 'Alternative',
#   'keywords': 'late night, empty seat, flash of light, broken heart, fall back into place',
#   'emotional': 'longing, waiting, fragility, hope, despair',
#   'synopsis': 'The lyrics describe a late night situation where someone is holding on, waiting for a sign or moment of happiness. The person expresses the fragility of the world and their own heart, wondering who will be there to help when things fall apart. The central theme is one of longing and waiting for a better time or place.'},
#  {'track_name': 'Hunnids',
#   'artist_name': 'Sainte',
#   'album_name': 'Local Mvp',
#   'genres': 'Rap/Hip Hop',
#   'keywords': 'grinds, get the bands, loot, treasure hunt, get the bag',
#   'emotional': 'pursuit, confidence, defensive, wealth, status',
#   'synopsis': 'The lyrics describe the pursuit of wealth and status with a crew, involving actions such as getting money, looking good, and standing out. The speakers are also cautious and defensive, referencing threats and weapons.'},
#  {'track_name': 'The Bit',
#   'artist_name': 'Melvins',
#   'album_name': 'Stag',
#   'genres': 'Rock, Alternative, Indie Rock/Rock pop',
#   'keywords': 'cows, size, force, life, death',
#   'emotional': 'confusion, struggle, life, death, reference',
#   'synopsis': 'The lyrics express a sense of confusion and struggle, with references to cows, force, life, and death.'}]

# %%
from nomic import atlas
import numpy as np
dataset = atlas.map_data(data = metadatas, 
                         embeddings=np.array([emb[1] for emb in embeddings]), 
                         identifier="grad_playlist_lyrics_metadata_e5")
# Out:
# 2024-03-23 15:31:38.150 | INFO     | nomic.dataset:_create_project:868 - Creating dataset `grad-playlist-lyrics-metadata-e5`
# 2024-03-23 15:31:38.482 | INFO     | nomic.atlas:map_data:108 - Uploading data to Atlas.
# 1it [00:01,  1.63s/it]
# 2024-03-23 15:31:40.139 | INFO     | nomic.dataset:_add_data:1537 - Upload succeeded.
# 2024-03-23 15:31:40.145 | INFO     | nomic.atlas:map_data:123 - `tyqnology/grad-playlist-lyrics-metadata-e5`: Data upload succeeded to dataset`
# 2024-03-23 15:31:40.583 | WARNING  | nomic.dataset:create_index:1116 - You did not specify the `topic_label_field` option in your topic_model, your dataset will not contain auto-labeled topics.
# 2024-03-23 15:31:41.867 | INFO     | nomic.dataset:create_index:1246 - Created map `grad_playlist_lyrics_metadata_e5` in dataset `tyqnology/grad-playlist-lyrics-metadata-e5`: https://atlas.nomic.ai/data/tyqnology/grad-playlist-lyrics-metadata-e5/map
